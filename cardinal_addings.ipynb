# %%
import pandas as pd
import numpy as np
from collections import Counter
import time
from PMTK.sampling.preferences_sampler import *
from PMTK.pref.preferences import *
from PMTK.utility.utility_solver import *
from PMTK.sampling.subset_samplers import *
from PMTK.utility.subset_finder import *
from PMTK.sampling.gibbs import *
from PMTK.data.film_dataset import *
from PMTK.sampling.decider import *
from PMTK.utility import *
from itertools import combinations
from sklearn import svm

def build_approx_theta(prf, init_theta = None):
    connivents = []
    if not init_theta:
        init_theta = [EMPTY_SET]
    theta = init_theta
    min_k = 1
    c  = get_connivent(theta, prf)
    cpt = 0
    while c:
        if not c in connivents:
            connivents.append(c)
        cit = get_candidate_iterator(c)
        skey = sorted(cit.keys())[0]
        b = False
        for k in cit:
            if b:
                break
            for i in cit[k]:
                s = set(i)
                for t in s:
                    b = b or (check_connivence_resolution(c, t) and not t in theta)
                    if not t in theta and check_connivence_resolution(c, t):
                        theta.append(t)
        c  = get_connivent(theta, prf)
        cpt = cpt + 1
        #print("solved connivent: ", cpt, " with", theta)
    a = additivity(theta)
    for c_i in connivents:
        cit = get_candidate_iterator(c_i)
        for k in cit:
            if k > a:
                break
            for i in cit[k]:
                for t in i:
                    if not t in theta and check_connivence_resolution(c_i,t):
                        theta.append(t)
    
    return theta

# %% [markdown]
# n_items = 6
# items = np.arange(n_items)
# ground_truth = Tierlist_Decider(items, p=0.3, alpha = 0.3)
# decider = Objective_Function(items, ground_truth)
#
# subsets = sample_subsets(items, n_subsets=10)
# for s in subsets:
#     decider(s)
#
# prf = decider.relation()
# theta = build_approx_theta(prf)

# %%
def train_cardinal_model(prf ,theta):
    mdl = utility_polyhedron(prf.items, theta, prf)
    mdl.maximize(-mdl.slack_sum)
    mdl.solve()
    d = {t : mdl.utilities[t].solution_value for t in mdl.utilities if mdl.utilities[t].solution_value != 0}
    return d

def evaluate_cardinal_model(cardinal_model, subset):
    s = 0
    for x in cardinal_model:
        if all(i in subset for i in x):
            s += cardinal_model[x]
    return s
        
        
def predict_cardinal(cardinal_model, items, subsets):
    prf = Preferences(items)
    for i_1 in range(len(subsets)):
        s_1 = subsets[i_1]
        e_1 = evaluate_cardinal_model(cardinal_model, s_1)
        for i_2 in range(i_1 + 1, len(subsets)):
            s_2 = subsets[i_2]
            e_2 = evaluate_cardinal_model(cardinal_model, s_2)
            if e_1 > e_2:
                prf.add_preference(s_1, s_2)
            if e_2 > e_1:
                prf.add_preference(s_2, s_1)
            if e_1 == e_2:
                prf.add_indifference(s_1, s_2)
    return prf


def train_svm_model(prf, theta, clf = None):
    if not clf:
        clf = svm.SVC()
    L = []
    for x,y in prf.preferred:
        v_x = list(vectorize_subset(x, theta))
        v_y = list(vectorize_subset(y, theta))
        L.append(np.array(v_x + v_y + [1]))
        L.append(np.array(v_y + v_x + [0]))
    data = np.array(L)
    X,y = data[:, :-1], data[:, -1]
    clf.fit(X,y)
    return clf

def predict_svm(svm_model,items, subsets, theta):
    prf = Preferences(items)
    for i_x in range(len(subsets)):
        x = subsets[i_x]
        for i_y in range(i_x+1, len(subsets)):
            y = subsets[i_y]
            v_x = list(vectorize_subset(x, theta))
            v_y = list(vectorize_subset(y, theta))
            v = np.array(v_x + v_y).reshape((1,-1))
            vi = np.array(v_y + v_x).reshape((1,-1))
            c = svm_model.predict(v)[0]
            ci = svm_model.predict(vi)[0]
            if c == 1 and ci == 0:
                prf.add_preference(x,y)
            if c == 0 and ci == 1:
                prf.add_preference(y,x)
    return prf

# %%
def build_approx_theta(prf, init_theta = None):
    connivents = []
    if not init_theta:
        init_theta = [EMPTY_SET]
    theta = init_theta
    min_k = 1
    c  = get_connivent(theta, prf)
    cpt = 0
    while c:
        if not c in connivents:
            connivents.append(c)
        cit = get_candidate_iterator(c)
        skey = sorted(cit.keys())[0]
        b = False
        for k in cit:
            if b:
                break
            for i in cit[k]:
                s = set(i)
                for t in s:
                    b = b or (check_connivence_resolution(c, t) and not t in theta)
                    if not t in theta and check_connivence_resolution(c, t):
                        theta.append(t)
        c  = get_connivent(theta, prf)
        cpt = cpt + 1
        #print("solved connivent: ", cpt, " with", theta)
    a = additivity(theta)
    for c_i in connivents:
        cit = get_candidate_iterator(c_i)
        for k in cit:
            if k > a:
                break
            for i in cit[k]:
                for t in i:
                    if not t in theta and check_connivence_resolution(c_i,t):
                        theta.append(t)
    
    return theta

def predict_from_mult_thetas(thetas,p, subsets):
    mdls = [utility_polyhedron(p.items, t, p) for t in thetas]
    prf = Preferences(p.items)
    for i_1 in range(len(subsets)):
        s_1 = subsets[i_1]
        for i_2 in range(i_1 + 1, len(subsets)):
            s_2 = subsets[i_2]
            r = [ordinal_dominance(s_1, s_2, mdl) for mdl in mdls]
            if all(i == "SUP" for i in r):
                prf.add_preference(s_1, s_2)
            elif all(i == "INF" for i in r):
                prf.add_preference(s_2, s_1)
            elif all(i == "EQ" for i in r):
                prf.add_indifference(s_1,s_2)
    return prf

def predict_from_theta(theta, p, subsets):
    mdl = utility_polyhedron(p.items, theta, p)
    prf = ordinal_peferences(p.items, subsets, mdl)
    return prf

def ACR(prf, decider):
    C = 0
    W = 0
    T = len(prf.preferred)
    for x,y in prf.preferred:
        if decider(x) > decider(y):
            C += 1
        elif decider(x) < decider(y):
            W += 1
    return C,W,T

def intersect_per_union(prf_1, prf_2):
    intersection = prf_1.intersection(prf_2)
    un = prf_1 + prf_2
    return len(intersection) / len(un)

# %%
n_items = 7
items = np.arange(n_items)
ground_truth = Tierlist_Decider(items, p=0.3, alpha = 0.3)
decider = Objective_Function(items, ground_truth)

budget = 35
n_subsets = 10

data = {
    "budget":[],
    "theta_definition":[],
    "theta_operator":[],
    "n_theta_min":[],
    "n_preferences":[],
    "additivity":[],
    "size":[],
    "sizes_sum":[],
    "time":[],
    "C":[],
    "W":[],
    "T":[],
}


for repetition in range(20):
    ground_truth = Tierlist_Decider(items, p=0.2, alpha = 0.2)
    decider = Objective_Function(items, ground_truth)

    for b in range(budget):
        s = sample_subset(items)
        while s in decider.saved:
            s = sample_subset(items)
            
        decider(s)
        prf = decider.relation()
        if len(prf) < 10:
            continue
            
        t_heuristic = build_approx_theta(prf, [EMPTY_SET])

        
        
        ti_lex_3 = time.time()
        t_lex3 = get_kernels_lex3(prf, get_all_k_sets(items, len(items)))
        ti_lex_3 = time.time() - ti_lex_3
        
        t_lex3_rnd = random.choice(t_lex3)
        t_lex3_union = union(t_lex3)
        
        
        print(f"Lex3 took {ti_lex_3:.2f}")


        for s_rep in range(10):
            print(f"repetition = {repetition}, b = {b}, srep = {s_rep}, npref = {len(prf)}")
            test_subsets = sample_subsets(items, n_subsets=n_subsets)
            #print(f"t_union = {t_union}, t_heuristic = {t_heuristic}, t_mins = {t_mins}, t_random = {t_random}")
            
            prf_t_heuristic = predict_from_theta(t_heuristic, prf, test_subsets) - prf

            prf_tlex3_union = predict_from_theta(t_lex3_union, prf, test_subsets) - prf
            prf_tlex3_rnd = predict_from_theta(t_lex3_rnd, prf, test_subsets) - prf
            prf_tlex3_all = predict_from_mult_thetas(t_lex3, prf, test_subsets) - prf
            
            svm_tlex3 = train_svm_model(prf, t_lex3_union, clf = None)
            prf_svm_tlex3 = predict_svm(svm_tlex3,prf.items, test_subsets, t_lex3_union) - prf
            
            card_tlex3 = train_cardinal_model(prf ,t_lex3_union)
            prf_card_tlex3 = predict_cardinal(card_tlex3, items, test_subsets) - prf            
            
            
            C_t_heuristic, W_t_heuritistic, T_t_heuristic = ACR(prf_t_heuristic, ground_truth)
        
            
            C_tlex3_union, W_tlex3_union, T_tlex3_union = ACR(prf_tlex3_union, ground_truth)
            C_tlex3_rnd, W_tlex3_rnd, T_tlex3_rnd = ACR(prf_tlex3_rnd, ground_truth)
            C_tlex3_all, W_tlex3_all, T_tlex3_all = ACR(prf_tlex3_all, ground_truth)
            C_svm_tlex3, W_svm_tlex3, T_svm_tlex3 = ACR(prf_svm_tlex3, ground_truth)
            C_card_tlex3, W_card_tlex3, T_card_tlex3 = ACR(prf_card_tlex3, ground_truth)

            

            
            ####LEX 3 
            data["budget"].append(b) 
            data["theta_definition"].append("LEX3")
            data["theta_operator"].append("UNION")
            data["time"].append(ti_lex_3)
            data["n_theta_min"].append(len(t_lex3))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex3_union))
            data["size"].append(len(t_lex3_union))
            data["sizes_sum"].append(sum(len(i) for i in t_lex3_union))
            data["C"].append(C_tlex3_union)
            data["W"].append(W_tlex3_union)
            data["T"].append(T_tlex3_union)
            
            data["budget"].append(b) 
            data["theta_definition"].append("LEX3")
            data["theta_operator"].append("RND")
            data["time"].append(ti_lex_3)
            data["n_theta_min"].append(len(t_lex3))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex3_rnd))
            data["size"].append(len(t_lex3_rnd))
            data["sizes_sum"].append(sum(len(i) for i in t_lex3_rnd))
            data["C"].append(C_tlex3_rnd)
            data["W"].append(W_tlex3_rnd)
            data["T"].append(T_tlex3_rnd)
            
            data["budget"].append(b) 
            data["theta_definition"].append("LEX3")
            data["theta_operator"].append("ALL")
            data["time"].append(ti_lex_3)
            data["n_theta_min"].append(len(t_lex3))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex3[0]))
            data["size"].append(len(t_lex3[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_lex3[0]))
            data["C"].append(C_tlex3_all)
            data["W"].append(W_tlex3_all)
            data["T"].append(T_tlex3_all)
            
            data["budget"].append(b) 
            data["theta_definition"].append("SVM")
            data["theta_operator"].append("SVM")
            data["time"].append(ti_lex_3)
            data["n_theta_min"].append(len(t_lex3))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex3[0]))
            data["size"].append(len(t_lex3[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_lex3[0]))
            data["C"].append(C_svm_tlex3)
            data["W"].append(W_svm_tlex3)
            data["T"].append(T_svm_tlex3)
            
            data["budget"].append(b) 
            data["theta_definition"].append("CARD")
            data["theta_operator"].append("CARD")
            data["time"].append(ti_lex_3)
            data["n_theta_min"].append(len(t_lex3))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex3[0]))
            data["size"].append(len(t_lex3[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_lex3[0]))
            data["C"].append(C_card_tlex3)
            data["W"].append(W_card_tlex3)
            data["T"].append(T_card_tlex3)
            
            df = pd.DataFrame(data)
            df.to_csv("theta_definitions_comparisons_with_cardinals_4.csv")
            #print(df)
# Out:
# Lex3 took 0.28
# repetition = 0, b = 5, srep = 0, npref = 11
# repetition = 0, b = 5, srep = 1, npref = 11
# repetition = 0, b = 5, srep = 2, npref = 11
# repetition = 0, b = 5, srep = 3, npref = 11
# repetition = 0, b = 5, srep = 4, npref = 11
# repetition = 0, b = 5, srep = 5, npref = 11
# repetition = 0, b = 5, srep = 6, npref = 11
# repetition = 0, b = 5, srep = 7, npref = 11
# repetition = 0, b = 5, srep = 8, npref = 11
# repetition = 0, b = 5, srep = 9, npref = 11
# Lex3 took 0.28
# repetition = 0, b = 6, srep = 0, npref = 17
# repetition = 0, b = 6, srep = 1, npref = 17
# repetition = 0, b = 6, srep = 2, npref = 17
# repetition = 0, b = 6, srep = 3, npref = 17
# repetition = 0, b = 6, srep = 4, npref = 17
# repetition = 0, b = 6, srep = 5, npref = 17
# repetition = 0, b = 6, srep = 6, npref = 17
# repetition = 0, b = 6, srep = 7, npref = 17
# repetition = 0, b = 6, srep = 8, npref = 17
# repetition = 0, b = 6, srep = 9, npref = 17
# Lex3 took 0.28
# repetition = 0, b = 7, srep = 0, npref = 21
# repetition = 0, b = 7, srep = 1, npref = 21
# repetition = 0, b = 7, srep = 2, npref = 21
# repetition = 0, b = 7, srep = 3, npref = 21
# repetition = 0, b = 7, srep = 4, npref = 21
# repetition = 0, b = 7, srep = 5, npref = 21
# repetition = 0, b = 7, srep = 6, npref = 21
# repetition = 0, b = 7, srep = 7, npref = 21
# repetition = 0, b = 7, srep = 8, npref = 21
# repetition = 0, b = 7, srep = 9, npref = 21
# Lex3 took 0.37
# repetition = 0, b = 8, srep = 0, npref = 25
# repetition = 0, b = 8, srep = 1, npref = 25
# repetition = 0, b = 8, srep = 2, npref = 25
# repetition = 0, b = 8, srep = 3, npref = 25
# repetition = 0, b = 8, srep = 4, npref = 25
# repetition = 0, b = 8, srep = 5, npref = 25
# repetition = 0, b = 8, srep = 6, npref = 25
# repetition = 0, b = 8, srep = 7, npref = 25
# repetition = 0, b = 8, srep = 8, npref = 25
# repetition = 0, b = 8, srep = 9, npref = 25
# Lex3 took 0.47
# repetition = 0, b = 9, srep = 0, npref = 33
# repetition = 0, b = 9, srep = 1, npref = 33
# repetition = 0, b = 9, srep = 2, npref = 33
# repetition = 0, b = 9, srep = 3, npref = 33
# repetition = 0, b = 9, srep = 4, npref = 33
# repetition = 0, b = 9, srep = 5, npref = 33
# repetition = 0, b = 9, srep = 6, npref = 33
# repetition = 0, b = 9, srep = 7, npref = 33
# repetition = 0, b = 9, srep = 8, npref = 33
# repetition = 0, b = 9, srep = 9, npref = 33
# Lex3 took 0.40
# repetition = 0, b = 10, srep = 0, npref = 42
# repetition = 0, b = 10, srep = 1, npref = 42
# repetition = 0, b = 10, srep = 2, npref = 42
# repetition = 0, b = 10, srep = 3, npref = 42
# repetition = 0, b = 10, srep = 4, npref = 42
# repetition = 0, b = 10, srep = 5, npref = 42
# repetition = 0, b = 10, srep = 6, npref = 42
# repetition = 0, b = 10, srep = 7, npref = 42
# repetition = 0, b = 10, srep = 8, npref = 42
# repetition = 0, b = 10, srep = 9, npref = 42
# Lex3 took 0.37
# repetition = 0, b = 11, srep = 0, npref = 48
# repetition = 0, b = 11, srep = 1, npref = 48
# repetition = 0, b = 11, srep = 2, npref = 48
# repetition = 0, b = 11, srep = 3, npref = 48
# repetition = 0, b = 11, srep = 4, npref = 48
# repetition = 0, b = 11, srep = 5, npref = 48
# repetition = 0, b = 11, srep = 6, npref = 48
# repetition = 0, b = 11, srep = 7, npref = 48
# repetition = 0, b = 11, srep = 8, npref = 48
# repetition = 0, b = 11, srep = 9, npref = 48
# Lex3 took 0.33
# repetition = 0, b = 12, srep = 0, npref = 54
# repetition = 0, b = 12, srep = 1, npref = 54
# repetition = 0, b = 12, srep = 2, npref = 54
# repetition = 0, b = 12, srep = 3, npref = 54
# repetition = 0, b = 12, srep = 4, npref = 54
# repetition = 0, b = 12, srep = 5, npref = 54
# repetition = 0, b = 12, srep = 6, npref = 54
# repetition = 0, b = 12, srep = 7, npref = 54
# repetition = 0, b = 12, srep = 8, npref = 54
# repetition = 0, b = 12, srep = 9, npref = 54
# Lex3 took 0.40
# repetition = 0, b = 13, srep = 0, npref = 65
# repetition = 0, b = 13, srep = 1, npref = 65
# repetition = 0, b = 13, srep = 2, npref = 65
# repetition = 0, b = 13, srep = 3, npref = 65
# repetition = 0, b = 13, srep = 4, npref = 65
# repetition = 0, b = 13, srep = 5, npref = 65
# repetition = 0, b = 13, srep = 6, npref = 65
# repetition = 0, b = 13, srep = 7, npref = 65
# repetition = 0, b = 13, srep = 8, npref = 65
# repetition = 0, b = 13, srep = 9, npref = 65
# Lex3 took 0.39
# repetition = 0, b = 14, srep = 0, npref = 72
# repetition = 0, b = 14, srep = 1, npref = 72
# repetition = 0, b = 14, srep = 2, npref = 72
# repetition = 0, b = 14, srep = 3, npref = 72
# repetition = 0, b = 14, srep = 4, npref = 72
# repetition = 0, b = 14, srep = 5, npref = 72
# repetition = 0, b = 14, srep = 6, npref = 72
# repetition = 0, b = 14, srep = 7, npref = 72
# repetition = 0, b = 14, srep = 8, npref = 72
# repetition = 0, b = 14, srep = 9, npref = 72
# Lex3 took 0.66
# repetition = 0, b = 15, srep = 0, npref = 85
# repetition = 0, b = 15, srep = 1, npref = 85
# repetition = 0, b = 15, srep = 2, npref = 85
# repetition = 0, b = 15, srep = 3, npref = 85
# repetition = 0, b = 15, srep = 4, npref = 85
# repetition = 0, b = 15, srep = 5, npref = 85
# repetition = 0, b = 15, srep = 6, npref = 85
# repetition = 0, b = 15, srep = 7, npref = 85
# repetition = 0, b = 15, srep = 8, npref = 85
# repetition = 0, b = 15, srep = 9, npref = 85
# Lex3 took 1.85
# repetition = 0, b = 16, srep = 0, npref = 98
# repetition = 0, b = 16, srep = 1, npref = 98
# repetition = 0, b = 16, srep = 2, npref = 98
# repetition = 0, b = 16, srep = 3, npref = 98
# repetition = 0, b = 16, srep = 4, npref = 98
# repetition = 0, b = 16, srep = 5, npref = 98
# repetition = 0, b = 16, srep = 6, npref = 98
# repetition = 0, b = 16, srep = 7, npref = 98
# repetition = 0, b = 16, srep = 8, npref = 98
# repetition = 0, b = 16, srep = 9, npref = 98
# Lex3 took 1.29
# repetition = 0, b = 17, srep = 0, npref = 115
# repetition = 0, b = 17, srep = 1, npref = 115
# repetition = 0, b = 17, srep = 2, npref = 115
# repetition = 0, b = 17, srep = 3, npref = 115
# repetition = 0, b = 17, srep = 4, npref = 115
# repetition = 0, b = 17, srep = 5, npref = 115
# repetition = 0, b = 17, srep = 6, npref = 115
# repetition = 0, b = 17, srep = 7, npref = 115
# repetition = 0, b = 17, srep = 8, npref = 115
# repetition = 0, b = 17, srep = 9, npref = 115
# Lex3 took 1.26
# repetition = 0, b = 18, srep = 0, npref = 125
# repetition = 0, b = 18, srep = 1, npref = 125
# repetition = 0, b = 18, srep = 2, npref = 125
# repetition = 0, b = 18, srep = 3, npref = 125
# repetition = 0, b = 18, srep = 4, npref = 125
# repetition = 0, b = 18, srep = 5, npref = 125
# repetition = 0, b = 18, srep = 6, npref = 125
# repetition = 0, b = 18, srep = 7, npref = 125
# repetition = 0, b = 18, srep = 8, npref = 125
# repetition = 0, b = 18, srep = 9, npref = 125
# Lex3 took 1.47
# repetition = 0, b = 19, srep = 0, npref = 141
# repetition = 0, b = 19, srep = 1, npref = 141
# repetition = 0, b = 19, srep = 2, npref = 141
# repetition = 0, b = 19, srep = 3, npref = 141
# repetition = 0, b = 19, srep = 4, npref = 141
# repetition = 0, b = 19, srep = 5, npref = 141
# repetition = 0, b = 19, srep = 6, npref = 141
# repetition = 0, b = 19, srep = 7, npref = 141
# repetition = 0, b = 19, srep = 8, npref = 141
# repetition = 0, b = 19, srep = 9, npref = 141
# Lex3 took 3.43
# repetition = 0, b = 20, srep = 0, npref = 157
# repetition = 0, b = 20, srep = 1, npref = 157
# repetition = 0, b = 20, srep = 2, npref = 157
# repetition = 0, b = 20, srep = 3, npref = 157
# repetition = 0, b = 20, srep = 4, npref = 157
# repetition = 0, b = 20, srep = 5, npref = 157
# repetition = 0, b = 20, srep = 6, npref = 157
# repetition = 0, b = 20, srep = 7, npref = 157
# repetition = 0, b = 20, srep = 8, npref = 157
# repetition = 0, b = 20, srep = 9, npref = 157
# Lex3 took 2.55
# repetition = 0, b = 21, srep = 0, npref = 173
# repetition = 0, b = 21, srep = 1, npref = 173
# repetition = 0, b = 21, srep = 2, npref = 173
# repetition = 0, b = 21, srep = 3, npref = 173
# repetition = 0, b = 21, srep = 4, npref = 173
# repetition = 0, b = 21, srep = 5, npref = 173
# repetition = 0, b = 21, srep = 6, npref = 173
# repetition = 0, b = 21, srep = 7, npref = 173
# repetition = 0, b = 21, srep = 8, npref = 173
# repetition = 0, b = 21, srep = 9, npref = 173
# Lex3 took 2.61
# repetition = 0, b = 22, srep = 0, npref = 186
# repetition = 0, b = 22, srep = 1, npref = 186
# repetition = 0, b = 22, srep = 2, npref = 186
# repetition = 0, b = 22, srep = 3, npref = 186
# repetition = 0, b = 22, srep = 4, npref = 186
# repetition = 0, b = 22, srep = 5, npref = 186
# repetition = 0, b = 22, srep = 6, npref = 186
# repetition = 0, b = 22, srep = 7, npref = 186
# repetition = 0, b = 22, srep = 8, npref = 186
# repetition = 0, b = 22, srep = 9, npref = 186
# Lex3 took 2.74
# repetition = 0, b = 23, srep = 0, npref = 203
# repetition = 0, b = 23, srep = 1, npref = 203
# repetition = 0, b = 23, srep = 2, npref = 203
# repetition = 0, b = 23, srep = 3, npref = 203
# repetition = 0, b = 23, srep = 4, npref = 203
# repetition = 0, b = 23, srep = 5, npref = 203
# repetition = 0, b = 23, srep = 6, npref = 203
# repetition = 0, b = 23, srep = 7, npref = 203
# repetition = 0, b = 23, srep = 8, npref = 203
# repetition = 0, b = 23, srep = 9, npref = 203
# Lex3 took 3.08
# repetition = 0, b = 24, srep = 0, npref = 225
# repetition = 0, b = 24, srep = 1, npref = 225
# repetition = 0, b = 24, srep = 2, npref = 225
# repetition = 0, b = 24, srep = 3, npref = 225
# repetition = 0, b = 24, srep = 4, npref = 225
# repetition = 0, b = 24, srep = 5, npref = 225
# repetition = 0, b = 24, srep = 6, npref = 225
# repetition = 0, b = 24, srep = 7, npref = 225
# repetition = 0, b = 24, srep = 8, npref = 225
# repetition = 0, b = 24, srep = 9, npref = 225
# Lex3 took 2.19
# repetition = 0, b = 25, srep = 0, npref = 246
# repetition = 0, b = 25, srep = 1, npref = 246
# repetition = 0, b = 25, srep = 2, npref = 246
# repetition = 0, b = 25, srep = 3, npref = 246
# repetition = 0, b = 25, srep = 4, npref = 246
# repetition = 0, b = 25, srep = 5, npref = 246
# repetition = 0, b = 25, srep = 6, npref = 246
# repetition = 0, b = 25, srep = 7, npref = 246
# repetition = 0, b = 25, srep = 8, npref = 246
# repetition = 0, b = 25, srep = 9, npref = 246
# Lex3 took 1.08
# repetition = 0, b = 26, srep = 0, npref = 267
# repetition = 0, b = 26, srep = 1, npref = 267
# repetition = 0, b = 26, srep = 2, npref = 267
# repetition = 0, b = 26, srep = 3, npref = 267
# repetition = 0, b = 26, srep = 4, npref = 267
# repetition = 0, b = 26, srep = 5, npref = 267
# repetition = 0, b = 26, srep = 6, npref = 267
# repetition = 0, b = 26, srep = 7, npref = 267
# repetition = 0, b = 26, srep = 8, npref = 267
# repetition = 0, b = 26, srep = 9, npref = 267
# Lex3 took 1.54
# repetition = 0, b = 27, srep = 0, npref = 288
# repetition = 0, b = 27, srep = 1, npref = 288
# repetition = 0, b = 27, srep = 2, npref = 288
# repetition = 0, b = 27, srep = 3, npref = 288
# repetition = 0, b = 27, srep = 4, npref = 288
# repetition = 0, b = 27, srep = 5, npref = 288
# repetition = 0, b = 27, srep = 6, npref = 288
# repetition = 0, b = 27, srep = 7, npref = 288
# repetition = 0, b = 27, srep = 8, npref = 288
# repetition = 0, b = 27, srep = 9, npref = 288
# Lex3 took 1.69
# repetition = 0, b = 28, srep = 0, npref = 309
# repetition = 0, b = 28, srep = 1, npref = 309
# repetition = 0, b = 28, srep = 2, npref = 309
# repetition = 0, b = 28, srep = 3, npref = 309
# repetition = 0, b = 28, srep = 4, npref = 309
# repetition = 0, b = 28, srep = 5, npref = 309
# repetition = 0, b = 28, srep = 6, npref = 309
# repetition = 0, b = 28, srep = 7, npref = 309
# repetition = 0, b = 28, srep = 8, npref = 309
# repetition = 0, b = 28, srep = 9, npref = 309
# Lex3 took 1.66
# repetition = 0, b = 29, srep = 0, npref = 330
# repetition = 0, b = 29, srep = 1, npref = 330
# repetition = 0, b = 29, srep = 2, npref = 330
# repetition = 0, b = 29, srep = 3, npref = 330
# repetition = 0, b = 29, srep = 4, npref = 330
# repetition = 0, b = 29, srep = 5, npref = 330
# repetition = 0, b = 29, srep = 6, npref = 330
# repetition = 0, b = 29, srep = 7, npref = 330
# repetition = 0, b = 29, srep = 8, npref = 330
# repetition = 0, b = 29, srep = 9, npref = 330
# Lex3 took 2.66
# repetition = 0, b = 30, srep = 0, npref = 357
# repetition = 0, b = 30, srep = 1, npref = 357
# repetition = 0, b = 30, srep = 2, npref = 357
# repetition = 0, b = 30, srep = 3, npref = 357
# repetition = 0, b = 30, srep = 4, npref = 357
# repetition = 0, b = 30, srep = 5, npref = 357
# repetition = 0, b = 30, srep = 6, npref = 357
# repetition = 0, b = 30, srep = 7, npref = 357
# repetition = 0, b = 30, srep = 8, npref = 357
# repetition = 0, b = 30, srep = 9, npref = 357
# Lex3 took 2.66
# repetition = 0, b = 31, srep = 0, npref = 379
# repetition = 0, b = 31, srep = 1, npref = 379
# repetition = 0, b = 31, srep = 2, npref = 379
# repetition = 0, b = 31, srep = 3, npref = 379
# repetition = 0, b = 31, srep = 4, npref = 379
# repetition = 0, b = 31, srep = 5, npref = 379
# repetition = 0, b = 31, srep = 6, npref = 379
# repetition = 0, b = 31, srep = 7, npref = 379
# repetition = 0, b = 31, srep = 8, npref = 379
# repetition = 0, b = 31, srep = 9, npref = 379
# Lex3 took 2.74
# repetition = 0, b = 32, srep = 0, npref = 401
# repetition = 0, b = 32, srep = 1, npref = 401
# repetition = 0, b = 32, srep = 2, npref = 401
# repetition = 0, b = 32, srep = 3, npref = 401
# repetition = 0, b = 32, srep = 4, npref = 401
# repetition = 0, b = 32, srep = 5, npref = 401
# repetition = 0, b = 32, srep = 6, npref = 401
# repetition = 0, b = 32, srep = 7, npref = 401
# repetition = 0, b = 32, srep = 8, npref = 401
# repetition = 0, b = 32, srep = 9, npref = 401
# Lex3 took 2.62
# repetition = 0, b = 33, srep = 0, npref = 423
# repetition = 0, b = 33, srep = 1, npref = 423
# repetition = 0, b = 33, srep = 2, npref = 423
# repetition = 0, b = 33, srep = 3, npref = 423
# repetition = 0, b = 33, srep = 4, npref = 423
# repetition = 0, b = 33, srep = 5, npref = 423
# repetition = 0, b = 33, srep = 6, npref = 423
# repetition = 0, b = 33, srep = 7, npref = 423
# repetition = 0, b = 33, srep = 8, npref = 423
# repetition = 0, b = 33, srep = 9, npref = 423
# Lex3 took 2.57
# repetition = 0, b = 34, srep = 0, npref = 447
# repetition = 0, b = 34, srep = 1, npref = 447
# repetition = 0, b = 34, srep = 2, npref = 447
# repetition = 0, b = 34, srep = 3, npref = 447
# repetition = 0, b = 34, srep = 4, npref = 447
# repetition = 0, b = 34, srep = 5, npref = 447
# repetition = 0, b = 34, srep = 6, npref = 447
# repetition = 0, b = 34, srep = 7, npref = 447
# repetition = 0, b = 34, srep = 8, npref = 447
# repetition = 0, b = 34, srep = 9, npref = 447
# Lex3 took 0.69
# repetition = 1, b = 5, srep = 0, npref = 11
# repetition = 1, b = 5, srep = 1, npref = 11
# repetition = 1, b = 5, srep = 2, npref = 11
# repetition = 1, b = 5, srep = 3, npref = 11
# repetition = 1, b = 5, srep = 4, npref = 11
# repetition = 1, b = 5, srep = 5, npref = 11
# repetition = 1, b = 5, srep = 6, npref = 11
# repetition = 1, b = 5, srep = 7, npref = 11
# repetition = 1, b = 5, srep = 8, npref = 11
# repetition = 1, b = 5, srep = 9, npref = 11
# Lex3 took 0.48
# repetition = 1, b = 6, srep = 0, npref = 17
# repetition = 1, b = 6, srep = 1, npref = 17
# repetition = 1, b = 6, srep = 2, npref = 17
# repetition = 1, b = 6, srep = 3, npref = 17
# repetition = 1, b = 6, srep = 4, npref = 17
# repetition = 1, b = 6, srep = 5, npref = 17
# repetition = 1, b = 6, srep = 6, npref = 17
# repetition = 1, b = 6, srep = 7, npref = 17
# repetition = 1, b = 6, srep = 8, npref = 17
# repetition = 1, b = 6, srep = 9, npref = 17
# Lex3 took 1.27
# repetition = 1, b = 7, srep = 0, npref = 23
# repetition = 1, b = 7, srep = 1, npref = 23
# repetition = 1, b = 7, srep = 2, npref = 23
# repetition = 1, b = 7, srep = 3, npref = 23
# repetition = 1, b = 7, srep = 4, npref = 23
# repetition = 1, b = 7, srep = 5, npref = 23
# repetition = 1, b = 7, srep = 6, npref = 23
# repetition = 1, b = 7, srep = 7, npref = 23
# repetition = 1, b = 7, srep = 8, npref = 23
# repetition = 1, b = 7, srep = 9, npref = 23
# Lex3 took 0.84
# repetition = 1, b = 8, srep = 0, npref = 29
# repetition = 1, b = 8, srep = 1, npref = 29
# repetition = 1, b = 8, srep = 2, npref = 29
# repetition = 1, b = 8, srep = 3, npref = 29
# repetition = 1, b = 8, srep = 4, npref = 29
# repetition = 1, b = 8, srep = 5, npref = 29
# repetition = 1, b = 8, srep = 6, npref = 29
# repetition = 1, b = 8, srep = 7, npref = 29
# repetition = 1, b = 8, srep = 8, npref = 29
# repetition = 1, b = 8, srep = 9, npref = 29
# Lex3 took 0.93
# repetition = 1, b = 9, srep = 0, npref = 35
# repetition = 1, b = 9, srep = 1, npref = 35
# repetition = 1, b = 9, srep = 2, npref = 35
# repetition = 1, b = 9, srep = 3, npref = 35
# repetition = 1, b = 9, srep = 4, npref = 35
# repetition = 1, b = 9, srep = 5, npref = 35
# repetition = 1, b = 9, srep = 6, npref = 35
# repetition = 1, b = 9, srep = 7, npref = 35
# repetition = 1, b = 9, srep = 8, npref = 35
# repetition = 1, b = 9, srep = 9, npref = 35
# Lex3 took 0.36
# repetition = 1, b = 10, srep = 0, npref = 45
# repetition = 1, b = 10, srep = 1, npref = 45
# repetition = 1, b = 10, srep = 2, npref = 45
# repetition = 1, b = 10, srep = 3, npref = 45
# repetition = 1, b = 10, srep = 4, npref = 45
# repetition = 1, b = 10, srep = 5, npref = 45
# repetition = 1, b = 10, srep = 6, npref = 45
# repetition = 1, b = 10, srep = 7, npref = 45
# repetition = 1, b = 10, srep = 8, npref = 45
# repetition = 1, b = 10, srep = 9, npref = 45
# Lex3 took 0.40
# repetition = 1, b = 11, srep = 0, npref = 53
# repetition = 1, b = 11, srep = 1, npref = 53
# repetition = 1, b = 11, srep = 2, npref = 53
# repetition = 1, b = 11, srep = 3, npref = 53
# repetition = 1, b = 11, srep = 4, npref = 53
# repetition = 1, b = 11, srep = 5, npref = 53
# repetition = 1, b = 11, srep = 6, npref = 53
# repetition = 1, b = 11, srep = 7, npref = 53
# repetition = 1, b = 11, srep = 8, npref = 53
# repetition = 1, b = 11, srep = 9, npref = 53
# Lex3 took 0.31
# repetition = 1, b = 12, srep = 0, npref = 61
# repetition = 1, b = 12, srep = 1, npref = 61
# repetition = 1, b = 12, srep = 2, npref = 61
# repetition = 1, b = 12, srep = 3, npref = 61
# repetition = 1, b = 12, srep = 4, npref = 61
# repetition = 1, b = 12, srep = 5, npref = 61
# repetition = 1, b = 12, srep = 6, npref = 61
# repetition = 1, b = 12, srep = 7, npref = 61
# repetition = 1, b = 12, srep = 8, npref = 61
# repetition = 1, b = 12, srep = 9, npref = 61
# Lex3 took 0.32
# repetition = 1, b = 13, srep = 0, npref = 70
# repetition = 1, b = 13, srep = 1, npref = 70
# repetition = 1, b = 13, srep = 2, npref = 70
# repetition = 1, b = 13, srep = 3, npref = 70
# repetition = 1, b = 13, srep = 4, npref = 70
# repetition = 1, b = 13, srep = 5, npref = 70
# repetition = 1, b = 13, srep = 6, npref = 70
# repetition = 1, b = 13, srep = 7, npref = 70
# repetition = 1, b = 13, srep = 8, npref = 70
# repetition = 1, b = 13, srep = 9, npref = 70
# Lex3 took 0.34
# repetition = 1, b = 14, srep = 0, npref = 79
# repetition = 1, b = 14, srep = 1, npref = 79
# repetition = 1, b = 14, srep = 2, npref = 79
# repetition = 1, b = 14, srep = 3, npref = 79
# repetition = 1, b = 14, srep = 4, npref = 79
# repetition = 1, b = 14, srep = 5, npref = 79
# repetition = 1, b = 14, srep = 6, npref = 79
# repetition = 1, b = 14, srep = 7, npref = 79
# repetition = 1, b = 14, srep = 8, npref = 79
# repetition = 1, b = 14, srep = 9, npref = 79
# Lex3 took 0.46
# repetition = 1, b = 15, srep = 0, npref = 88
# repetition = 1, b = 15, srep = 1, npref = 88
# repetition = 1, b = 15, srep = 2, npref = 88
# repetition = 1, b = 15, srep = 3, npref = 88
# repetition = 1, b = 15, srep = 4, npref = 88
# repetition = 1, b = 15, srep = 5, npref = 88
# repetition = 1, b = 15, srep = 6, npref = 88
# repetition = 1, b = 15, srep = 7, npref = 88
# repetition = 1, b = 15, srep = 8, npref = 88
# repetition = 1, b = 15, srep = 9, npref = 88
# Lex3 took 0.39
# repetition = 1, b = 16, srep = 0, npref = 97
# repetition = 1, b = 16, srep = 1, npref = 97
# repetition = 1, b = 16, srep = 2, npref = 97
# repetition = 1, b = 16, srep = 3, npref = 97
# repetition = 1, b = 16, srep = 4, npref = 97
# repetition = 1, b = 16, srep = 5, npref = 97
# repetition = 1, b = 16, srep = 6, npref = 97
# repetition = 1, b = 16, srep = 7, npref = 97
# repetition = 1, b = 16, srep = 8, npref = 97
# repetition = 1, b = 16, srep = 9, npref = 97
# Lex3 took 0.42
# repetition = 1, b = 17, srep = 0, npref = 106
# repetition = 1, b = 17, srep = 1, npref = 106
# repetition = 1, b = 17, srep = 2, npref = 106
# repetition = 1, b = 17, srep = 3, npref = 106
# repetition = 1, b = 17, srep = 4, npref = 106
# repetition = 1, b = 17, srep = 5, npref = 106
# repetition = 1, b = 17, srep = 6, npref = 106
# repetition = 1, b = 17, srep = 7, npref = 106
# repetition = 1, b = 17, srep = 8, npref = 106
# repetition = 1, b = 17, srep = 9, npref = 106
# Lex3 took 0.45
# repetition = 1, b = 18, srep = 0, npref = 119
# repetition = 1, b = 18, srep = 1, npref = 119
# repetition = 1, b = 18, srep = 2, npref = 119
# repetition = 1, b = 18, srep = 3, npref = 119
# repetition = 1, b = 18, srep = 4, npref = 119
# repetition = 1, b = 18, srep = 5, npref = 119
# repetition = 1, b = 18, srep = 6, npref = 119
# repetition = 1, b = 18, srep = 7, npref = 119
# repetition = 1, b = 18, srep = 8, npref = 119
# repetition = 1, b = 18, srep = 9, npref = 119
# Lex3 took 0.45
# repetition = 1, b = 19, srep = 0, npref = 129
# repetition = 1, b = 19, srep = 1, npref = 129
# repetition = 1, b = 19, srep = 2, npref = 129
# repetition = 1, b = 19, srep = 3, npref = 129
# repetition = 1, b = 19, srep = 4, npref = 129
# repetition = 1, b = 19, srep = 5, npref = 129
# repetition = 1, b = 19, srep = 6, npref = 129
# repetition = 1, b = 19, srep = 7, npref = 129
# repetition = 1, b = 19, srep = 8, npref = 129
# repetition = 1, b = 19, srep = 9, npref = 129
# Lex3 took 0.68
# repetition = 1, b = 20, srep = 0, npref = 147
# repetition = 1, b = 20, srep = 1, npref = 147
# repetition = 1, b = 20, srep = 2, npref = 147
# repetition = 1, b = 20, srep = 3, npref = 147
# repetition = 1, b = 20, srep = 4, npref = 147
# repetition = 1, b = 20, srep = 5, npref = 147
# repetition = 1, b = 20, srep = 6, npref = 147
# repetition = 1, b = 20, srep = 7, npref = 147
# repetition = 1, b = 20, srep = 8, npref = 147
# repetition = 1, b = 20, srep = 9, npref = 147
# Lex3 took 1.72
# repetition = 1, b = 21, srep = 0, npref = 165
# repetition = 1, b = 21, srep = 1, npref = 165
# repetition = 1, b = 21, srep = 2, npref = 165
# repetition = 1, b = 21, srep = 3, npref = 165
# repetition = 1, b = 21, srep = 4, npref = 165
# repetition = 1, b = 21, srep = 5, npref = 165
# repetition = 1, b = 21, srep = 6, npref = 165
# repetition = 1, b = 21, srep = 7, npref = 165
# repetition = 1, b = 21, srep = 8, npref = 165
# repetition = 1, b = 21, srep = 9, npref = 165
# Lex3 took 1.57
# repetition = 1, b = 22, srep = 0, npref = 181
# repetition = 1, b = 22, srep = 1, npref = 181
# repetition = 1, b = 22, srep = 2, npref = 181
# repetition = 1, b = 22, srep = 3, npref = 181
# repetition = 1, b = 22, srep = 4, npref = 181
# repetition = 1, b = 22, srep = 5, npref = 181
# repetition = 1, b = 22, srep = 6, npref = 181
# repetition = 1, b = 22, srep = 7, npref = 181
# repetition = 1, b = 22, srep = 8, npref = 181
# repetition = 1, b = 22, srep = 9, npref = 181
# Lex3 took 1.55
# repetition = 1, b = 23, srep = 0, npref = 200
# repetition = 1, b = 23, srep = 1, npref = 200
# repetition = 1, b = 23, srep = 2, npref = 200
# repetition = 1, b = 23, srep = 3, npref = 200
# repetition = 1, b = 23, srep = 4, npref = 200
# repetition = 1, b = 23, srep = 5, npref = 200
# repetition = 1, b = 23, srep = 6, npref = 200
# repetition = 1, b = 23, srep = 7, npref = 200
# repetition = 1, b = 23, srep = 8, npref = 200
# repetition = 1, b = 23, srep = 9, npref = 200
# Lex3 took 0.89
# repetition = 1, b = 24, srep = 0, npref = 219
# repetition = 1, b = 24, srep = 1, npref = 219
# repetition = 1, b = 24, srep = 2, npref = 219
# repetition = 1, b = 24, srep = 3, npref = 219
# repetition = 1, b = 24, srep = 4, npref = 219
# repetition = 1, b = 24, srep = 5, npref = 219
# repetition = 1, b = 24, srep = 6, npref = 219
# repetition = 1, b = 24, srep = 7, npref = 219
# repetition = 1, b = 24, srep = 8, npref = 219
# repetition = 1, b = 24, srep = 9, npref = 219
# Lex3 took 0.93
# repetition = 1, b = 25, srep = 0, npref = 234
# repetition = 1, b = 25, srep = 1, npref = 234
# repetition = 1, b = 25, srep = 2, npref = 234
# repetition = 1, b = 25, srep = 3, npref = 234
# repetition = 1, b = 25, srep = 4, npref = 234
# repetition = 1, b = 25, srep = 5, npref = 234
# repetition = 1, b = 25, srep = 6, npref = 234
# repetition = 1, b = 25, srep = 7, npref = 234
# repetition = 1, b = 25, srep = 8, npref = 234
# repetition = 1, b = 25, srep = 9, npref = 234
# Lex3 took 0.92
# repetition = 1, b = 26, srep = 0, npref = 253
# repetition = 1, b = 26, srep = 1, npref = 253
# repetition = 1, b = 26, srep = 2, npref = 253
# repetition = 1, b = 26, srep = 3, npref = 253
# repetition = 1, b = 26, srep = 4, npref = 253
# repetition = 1, b = 26, srep = 5, npref = 253
# repetition = 1, b = 26, srep = 6, npref = 253
# repetition = 1, b = 26, srep = 7, npref = 253
# repetition = 1, b = 26, srep = 8, npref = 253
# repetition = 1, b = 26, srep = 9, npref = 253
# Lex3 took 1.17
# repetition = 1, b = 27, srep = 0, npref = 269
# repetition = 1, b = 27, srep = 1, npref = 269
# repetition = 1, b = 27, srep = 2, npref = 269
# repetition = 1, b = 27, srep = 3, npref = 269
# repetition = 1, b = 27, srep = 4, npref = 269
# repetition = 1, b = 27, srep = 5, npref = 269
# repetition = 1, b = 27, srep = 6, npref = 269
# repetition = 1, b = 27, srep = 7, npref = 269
# repetition = 1, b = 27, srep = 8, npref = 269
# repetition = 1, b = 27, srep = 9, npref = 269
# Lex3 took 1.06
# repetition = 1, b = 28, srep = 0, npref = 285
# repetition = 1, b = 28, srep = 1, npref = 285
# repetition = 1, b = 28, srep = 2, npref = 285
# repetition = 1, b = 28, srep = 3, npref = 285
# repetition = 1, b = 28, srep = 4, npref = 285
# repetition = 1, b = 28, srep = 5, npref = 285
# repetition = 1, b = 28, srep = 6, npref = 285
# repetition = 1, b = 28, srep = 7, npref = 285
# repetition = 1, b = 28, srep = 8, npref = 285
# repetition = 1, b = 28, srep = 9, npref = 285
# Lex3 took 1.20
# repetition = 1, b = 29, srep = 0, npref = 308
# repetition = 1, b = 29, srep = 1, npref = 308
# repetition = 1, b = 29, srep = 2, npref = 308
# repetition = 1, b = 29, srep = 3, npref = 308
# repetition = 1, b = 29, srep = 4, npref = 308
# repetition = 1, b = 29, srep = 5, npref = 308
# repetition = 1, b = 29, srep = 6, npref = 308
# repetition = 1, b = 29, srep = 7, npref = 308
# repetition = 1, b = 29, srep = 8, npref = 308
# repetition = 1, b = 29, srep = 9, npref = 308
# Lex3 took 1.18
# repetition = 1, b = 30, srep = 0, npref = 330
# repetition = 1, b = 30, srep = 1, npref = 330
# repetition = 1, b = 30, srep = 2, npref = 330
# repetition = 1, b = 30, srep = 3, npref = 330
# repetition = 1, b = 30, srep = 4, npref = 330
# repetition = 1, b = 30, srep = 5, npref = 330
# repetition = 1, b = 30, srep = 6, npref = 330
# repetition = 1, b = 30, srep = 7, npref = 330
# repetition = 1, b = 30, srep = 8, npref = 330
# repetition = 1, b = 30, srep = 9, npref = 330
# Lex3 took 1.35
# repetition = 1, b = 31, srep = 0, npref = 348
# repetition = 1, b = 31, srep = 1, npref = 348
# repetition = 1, b = 31, srep = 2, npref = 348
# repetition = 1, b = 31, srep = 3, npref = 348
# repetition = 1, b = 31, srep = 4, npref = 348
# repetition = 1, b = 31, srep = 5, npref = 348
# repetition = 1, b = 31, srep = 6, npref = 348
# repetition = 1, b = 31, srep = 7, npref = 348
# repetition = 1, b = 31, srep = 8, npref = 348
# repetition = 1, b = 31, srep = 9, npref = 348
# Lex3 took 1.22
# repetition = 1, b = 32, srep = 0, npref = 366
# repetition = 1, b = 32, srep = 1, npref = 366
# repetition = 1, b = 32, srep = 2, npref = 366
# repetition = 1, b = 32, srep = 3, npref = 366
# repetition = 1, b = 32, srep = 4, npref = 366
# repetition = 1, b = 32, srep = 5, npref = 366
# repetition = 1, b = 32, srep = 6, npref = 366
# repetition = 1, b = 32, srep = 7, npref = 366
# repetition = 1, b = 32, srep = 8, npref = 366
# repetition = 1, b = 32, srep = 9, npref = 366
# Lex3 took 1.44
# repetition = 1, b = 33, srep = 0, npref = 398
# repetition = 1, b = 33, srep = 1, npref = 398
# repetition = 1, b = 33, srep = 2, npref = 398
# repetition = 1, b = 33, srep = 3, npref = 398
# repetition = 1, b = 33, srep = 4, npref = 398
# repetition = 1, b = 33, srep = 5, npref = 398
# repetition = 1, b = 33, srep = 6, npref = 398
# repetition = 1, b = 33, srep = 7, npref = 398
# repetition = 1, b = 33, srep = 8, npref = 398
# repetition = 1, b = 33, srep = 9, npref = 398
# Lex3 took 1.33
# repetition = 1, b = 34, srep = 0, npref = 417
# repetition = 1, b = 34, srep = 1, npref = 417
# repetition = 1, b = 34, srep = 2, npref = 417
# repetition = 1, b = 34, srep = 3, npref = 417
# repetition = 1, b = 34, srep = 4, npref = 417
# repetition = 1, b = 34, srep = 5, npref = 417
# repetition = 1, b = 34, srep = 6, npref = 417
# repetition = 1, b = 34, srep = 7, npref = 417
# repetition = 1, b = 34, srep = 8, npref = 417
# repetition = 1, b = 34, srep = 9, npref = 417
# Lex3 took 0.38
# repetition = 2, b = 5, srep = 0, npref = 12
# repetition = 2, b = 5, srep = 1, npref = 12
# repetition = 2, b = 5, srep = 2, npref = 12
# repetition = 2, b = 5, srep = 3, npref = 12
# repetition = 2, b = 5, srep = 4, npref = 12
# repetition = 2, b = 5, srep = 5, npref = 12
# repetition = 2, b = 5, srep = 6, npref = 12
# repetition = 2, b = 5, srep = 7, npref = 12
# repetition = 2, b = 5, srep = 8, npref = 12
# repetition = 2, b = 5, srep = 9, npref = 12
# Lex3 took 0.29
# repetition = 2, b = 6, srep = 0, npref = 17
# repetition = 2, b = 6, srep = 1, npref = 17
# repetition = 2, b = 6, srep = 2, npref = 17
# repetition = 2, b = 6, srep = 3, npref = 17
# repetition = 2, b = 6, srep = 4, npref = 17
# repetition = 2, b = 6, srep = 5, npref = 17
# repetition = 2, b = 6, srep = 6, npref = 17
# repetition = 2, b = 6, srep = 7, npref = 17
# repetition = 2, b = 6, srep = 8, npref = 17
# repetition = 2, b = 6, srep = 9, npref = 17
# Lex3 took 0.63
# repetition = 2, b = 7, srep = 0, npref = 24
# repetition = 2, b = 7, srep = 1, npref = 24
# repetition = 2, b = 7, srep = 2, npref = 24
# repetition = 2, b = 7, srep = 3, npref = 24
# repetition = 2, b = 7, srep = 4, npref = 24
# repetition = 2, b = 7, srep = 5, npref = 24
# repetition = 2, b = 7, srep = 6, npref = 24
# repetition = 2, b = 7, srep = 7, npref = 24
# repetition = 2, b = 7, srep = 8, npref = 24
# repetition = 2, b = 7, srep = 9, npref = 24
# Lex3 took 0.77
# repetition = 2, b = 8, srep = 0, npref = 31
# repetition = 2, b = 8, srep = 1, npref = 31
# repetition = 2, b = 8, srep = 2, npref = 31
# repetition = 2, b = 8, srep = 3, npref = 31
# repetition = 2, b = 8, srep = 4, npref = 31
# repetition = 2, b = 8, srep = 5, npref = 31
# repetition = 2, b = 8, srep = 6, npref = 31
# repetition = 2, b = 8, srep = 7, npref = 31
# repetition = 2, b = 8, srep = 8, npref = 31
# repetition = 2, b = 8, srep = 9, npref = 31
# Lex3 took 0.51
# repetition = 2, b = 9, srep = 0, npref = 38
# repetition = 2, b = 9, srep = 1, npref = 38
# repetition = 2, b = 9, srep = 2, npref = 38
# repetition = 2, b = 9, srep = 3, npref = 38
# repetition = 2, b = 9, srep = 4, npref = 38
# repetition = 2, b = 9, srep = 5, npref = 38
# repetition = 2, b = 9, srep = 6, npref = 38
# repetition = 2, b = 9, srep = 7, npref = 38
# repetition = 2, b = 9, srep = 8, npref = 38
# repetition = 2, b = 9, srep = 9, npref = 38
# Lex3 took 0.44
# repetition = 2, b = 10, srep = 0, npref = 46
# repetition = 2, b = 10, srep = 1, npref = 46
# repetition = 2, b = 10, srep = 2, npref = 46
# repetition = 2, b = 10, srep = 3, npref = 46
# repetition = 2, b = 10, srep = 4, npref = 46
# repetition = 2, b = 10, srep = 5, npref = 46
# repetition = 2, b = 10, srep = 6, npref = 46
# repetition = 2, b = 10, srep = 7, npref = 46
# repetition = 2, b = 10, srep = 8, npref = 46
# repetition = 2, b = 10, srep = 9, npref = 46
# Lex3 took 0.45
# repetition = 2, b = 11, srep = 0, npref = 54
# repetition = 2, b = 11, srep = 1, npref = 54
# repetition = 2, b = 11, srep = 2, npref = 54
# repetition = 2, b = 11, srep = 3, npref = 54
# repetition = 2, b = 11, srep = 4, npref = 54
# repetition = 2, b = 11, srep = 5, npref = 54
# repetition = 2, b = 11, srep = 6, npref = 54
# repetition = 2, b = 11, srep = 7, npref = 54
# repetition = 2, b = 11, srep = 8, npref = 54
# repetition = 2, b = 11, srep = 9, npref = 54
# Lex3 took 0.34
# repetition = 2, b = 12, srep = 0, npref = 62
# repetition = 2, b = 12, srep = 1, npref = 62
# repetition = 2, b = 12, srep = 2, npref = 62
# repetition = 2, b = 12, srep = 3, npref = 62
# repetition = 2, b = 12, srep = 4, npref = 62
# repetition = 2, b = 12, srep = 5, npref = 62
# repetition = 2, b = 12, srep = 6, npref = 62
# repetition = 2, b = 12, srep = 7, npref = 62
# repetition = 2, b = 12, srep = 8, npref = 62
# repetition = 2, b = 12, srep = 9, npref = 62
# Lex3 took 0.43
# repetition = 2, b = 13, srep = 0, npref = 70
# repetition = 2, b = 13, srep = 1, npref = 70
# repetition = 2, b = 13, srep = 2, npref = 70
# repetition = 2, b = 13, srep = 3, npref = 70
# repetition = 2, b = 13, srep = 4, npref = 70
# repetition = 2, b = 13, srep = 5, npref = 70
# repetition = 2, b = 13, srep = 6, npref = 70
# repetition = 2, b = 13, srep = 7, npref = 70
# repetition = 2, b = 13, srep = 8, npref = 70
# repetition = 2, b = 13, srep = 9, npref = 70
# Lex3 took 1.87
# repetition = 2, b = 14, srep = 0, npref = 81
# repetition = 2, b = 14, srep = 1, npref = 81
# repetition = 2, b = 14, srep = 2, npref = 81
# repetition = 2, b = 14, srep = 3, npref = 81
# repetition = 2, b = 14, srep = 4, npref = 81
# repetition = 2, b = 14, srep = 5, npref = 81
# repetition = 2, b = 14, srep = 6, npref = 81
# repetition = 2, b = 14, srep = 7, npref = 81
# repetition = 2, b = 14, srep = 8, npref = 81
# repetition = 2, b = 14, srep = 9, npref = 81
# Lex3 took 1.09
# repetition = 2, b = 15, srep = 0, npref = 95
# repetition = 2, b = 15, srep = 1, npref = 95
# repetition = 2, b = 15, srep = 2, npref = 95
# repetition = 2, b = 15, srep = 3, npref = 95
# repetition = 2, b = 15, srep = 4, npref = 95
# repetition = 2, b = 15, srep = 5, npref = 95
# repetition = 2, b = 15, srep = 6, npref = 95
# repetition = 2, b = 15, srep = 7, npref = 95
# repetition = 2, b = 15, srep = 8, npref = 95
# repetition = 2, b = 15, srep = 9, npref = 95
# Lex3 took 0.83
# repetition = 2, b = 16, srep = 0, npref = 108
# repetition = 2, b = 16, srep = 1, npref = 108
# repetition = 2, b = 16, srep = 2, npref = 108
# repetition = 2, b = 16, srep = 3, npref = 108
# repetition = 2, b = 16, srep = 4, npref = 108
# repetition = 2, b = 16, srep = 5, npref = 108
# repetition = 2, b = 16, srep = 6, npref = 108
# repetition = 2, b = 16, srep = 7, npref = 108
# repetition = 2, b = 16, srep = 8, npref = 108
# repetition = 2, b = 16, srep = 9, npref = 108
# Lex3 took 2.33
# repetition = 2, b = 17, srep = 0, npref = 119
# repetition = 2, b = 17, srep = 1, npref = 119
# repetition = 2, b = 17, srep = 2, npref = 119
# repetition = 2, b = 17, srep = 3, npref = 119
# repetition = 2, b = 17, srep = 4, npref = 119
# repetition = 2, b = 17, srep = 5, npref = 119
# repetition = 2, b = 17, srep = 6, npref = 119
# repetition = 2, b = 17, srep = 7, npref = 119
# repetition = 2, b = 17, srep = 8, npref = 119
# repetition = 2, b = 17, srep = 9, npref = 119
# Lex3 took 1.76
# repetition = 2, b = 18, srep = 0, npref = 133
# repetition = 2, b = 18, srep = 1, npref = 133
# repetition = 2, b = 18, srep = 2, npref = 133
# repetition = 2, b = 18, srep = 3, npref = 133
# repetition = 2, b = 18, srep = 4, npref = 133
# repetition = 2, b = 18, srep = 5, npref = 133
# repetition = 2, b = 18, srep = 6, npref = 133
# repetition = 2, b = 18, srep = 7, npref = 133
# repetition = 2, b = 18, srep = 8, npref = 133
# repetition = 2, b = 18, srep = 9, npref = 133
# Lex3 took 1.76
# repetition = 2, b = 19, srep = 0, npref = 147
# repetition = 2, b = 19, srep = 1, npref = 147
# repetition = 2, b = 19, srep = 2, npref = 147
# repetition = 2, b = 19, srep = 3, npref = 147
# repetition = 2, b = 19, srep = 4, npref = 147
# repetition = 2, b = 19, srep = 5, npref = 147
# repetition = 2, b = 19, srep = 6, npref = 147
# repetition = 2, b = 19, srep = 7, npref = 147
# repetition = 2, b = 19, srep = 8, npref = 147
# repetition = 2, b = 19, srep = 9, npref = 147
# Lex3 took 1.76
# repetition = 2, b = 20, srep = 0, npref = 160
# repetition = 2, b = 20, srep = 1, npref = 160
# repetition = 2, b = 20, srep = 2, npref = 160
# repetition = 2, b = 20, srep = 3, npref = 160
# repetition = 2, b = 20, srep = 4, npref = 160
# repetition = 2, b = 20, srep = 5, npref = 160
# repetition = 2, b = 20, srep = 6, npref = 160
# repetition = 2, b = 20, srep = 7, npref = 160
# repetition = 2, b = 20, srep = 8, npref = 160
# repetition = 2, b = 20, srep = 9, npref = 160
# Lex3 took 1.73
# repetition = 2, b = 21, srep = 0, npref = 175
# repetition = 2, b = 21, srep = 1, npref = 175
# repetition = 2, b = 21, srep = 2, npref = 175
# repetition = 2, b = 21, srep = 3, npref = 175
# repetition = 2, b = 21, srep = 4, npref = 175
# repetition = 2, b = 21, srep = 5, npref = 175
# repetition = 2, b = 21, srep = 6, npref = 175
# repetition = 2, b = 21, srep = 7, npref = 175
# repetition = 2, b = 21, srep = 8, npref = 175
# repetition = 2, b = 21, srep = 9, npref = 175
# Lex3 took 1.71
# repetition = 2, b = 22, srep = 0, npref = 189
# repetition = 2, b = 22, srep = 1, npref = 189
# repetition = 2, b = 22, srep = 2, npref = 189
# repetition = 2, b = 22, srep = 3, npref = 189
# repetition = 2, b = 22, srep = 4, npref = 189
# repetition = 2, b = 22, srep = 5, npref = 189
# repetition = 2, b = 22, srep = 6, npref = 189
# repetition = 2, b = 22, srep = 7, npref = 189
# repetition = 2, b = 22, srep = 8, npref = 189
# repetition = 2, b = 22, srep = 9, npref = 189
# Lex3 took 1.69
# repetition = 2, b = 23, srep = 0, npref = 205
# repetition = 2, b = 23, srep = 1, npref = 205
# repetition = 2, b = 23, srep = 2, npref = 205
# repetition = 2, b = 23, srep = 3, npref = 205
# repetition = 2, b = 23, srep = 4, npref = 205
# repetition = 2, b = 23, srep = 5, npref = 205
# repetition = 2, b = 23, srep = 6, npref = 205
# repetition = 2, b = 23, srep = 7, npref = 205
# repetition = 2, b = 23, srep = 8, npref = 205
# repetition = 2, b = 23, srep = 9, npref = 205
# Lex3 took 1.74
# repetition = 2, b = 24, srep = 0, npref = 228
# repetition = 2, b = 24, srep = 1, npref = 228
# repetition = 2, b = 24, srep = 2, npref = 228
# repetition = 2, b = 24, srep = 3, npref = 228
# repetition = 2, b = 24, srep = 4, npref = 228
# repetition = 2, b = 24, srep = 5, npref = 228
# repetition = 2, b = 24, srep = 6, npref = 228
# repetition = 2, b = 24, srep = 7, npref = 228
# repetition = 2, b = 24, srep = 8, npref = 228
# repetition = 2, b = 24, srep = 9, npref = 228
# Lex3 took 1.56
# repetition = 2, b = 25, srep = 0, npref = 244
# repetition = 2, b = 25, srep = 1, npref = 244
# repetition = 2, b = 25, srep = 2, npref = 244
# repetition = 2, b = 25, srep = 3, npref = 244
# repetition = 2, b = 25, srep = 4, npref = 244
# repetition = 2, b = 25, srep = 5, npref = 244
# repetition = 2, b = 25, srep = 6, npref = 244
# repetition = 2, b = 25, srep = 7, npref = 244
# repetition = 2, b = 25, srep = 8, npref = 244
# repetition = 2, b = 25, srep = 9, npref = 244
# Lex3 took 1.87
# repetition = 2, b = 26, srep = 0, npref = 262
# repetition = 2, b = 26, srep = 1, npref = 262
# repetition = 2, b = 26, srep = 2, npref = 262
# repetition = 2, b = 26, srep = 3, npref = 262
# repetition = 2, b = 26, srep = 4, npref = 262
# repetition = 2, b = 26, srep = 5, npref = 262
# repetition = 2, b = 26, srep = 6, npref = 262
# repetition = 2, b = 26, srep = 7, npref = 262
# repetition = 2, b = 26, srep = 8, npref = 262
# repetition = 2, b = 26, srep = 9, npref = 262
# Lex3 took 1.61
# repetition = 2, b = 27, srep = 0, npref = 279
# repetition = 2, b = 27, srep = 1, npref = 279
# repetition = 2, b = 27, srep = 2, npref = 279
# repetition = 2, b = 27, srep = 3, npref = 279
# repetition = 2, b = 27, srep = 4, npref = 279
# repetition = 2, b = 27, srep = 5, npref = 279
# repetition = 2, b = 27, srep = 6, npref = 279
# repetition = 2, b = 27, srep = 7, npref = 279
# repetition = 2, b = 27, srep = 8, npref = 279
# repetition = 2, b = 27, srep = 9, npref = 279
# Lex3 took 1.78
# repetition = 2, b = 28, srep = 0, npref = 303
# repetition = 2, b = 28, srep = 1, npref = 303
# repetition = 2, b = 28, srep = 2, npref = 303
# repetition = 2, b = 28, srep = 3, npref = 303
# repetition = 2, b = 28, srep = 4, npref = 303
# repetition = 2, b = 28, srep = 5, npref = 303
# repetition = 2, b = 28, srep = 6, npref = 303
# repetition = 2, b = 28, srep = 7, npref = 303
# repetition = 2, b = 28, srep = 8, npref = 303
# repetition = 2, b = 28, srep = 9, npref = 303
# Lex3 took 1.81
# repetition = 2, b = 29, srep = 0, npref = 321
# repetition = 2, b = 29, srep = 1, npref = 321
# repetition = 2, b = 29, srep = 2, npref = 321
# repetition = 2, b = 29, srep = 3, npref = 321
# repetition = 2, b = 29, srep = 4, npref = 321
# repetition = 2, b = 29, srep = 5, npref = 321
# repetition = 2, b = 29, srep = 6, npref = 321
# repetition = 2, b = 29, srep = 7, npref = 321
# repetition = 2, b = 29, srep = 8, npref = 321
# repetition = 2, b = 29, srep = 9, npref = 321
# Lex3 took 1.87
# repetition = 2, b = 30, srep = 0, npref = 342
# repetition = 2, b = 30, srep = 1, npref = 342
# repetition = 2, b = 30, srep = 2, npref = 342
# repetition = 2, b = 30, srep = 3, npref = 342
# repetition = 2, b = 30, srep = 4, npref = 342
# repetition = 2, b = 30, srep = 5, npref = 342
# repetition = 2, b = 30, srep = 6, npref = 342
# repetition = 2, b = 30, srep = 7, npref = 342
# repetition = 2, b = 30, srep = 8, npref = 342
# repetition = 2, b = 30, srep = 9, npref = 342
# Lex3 took 1.92
# repetition = 2, b = 31, srep = 0, npref = 361
# repetition = 2, b = 31, srep = 1, npref = 361
# repetition = 2, b = 31, srep = 2, npref = 361
# repetition = 2, b = 31, srep = 3, npref = 361
# repetition = 2, b = 31, srep = 4, npref = 361
# repetition = 2, b = 31, srep = 5, npref = 361
# repetition = 2, b = 31, srep = 6, npref = 361
# repetition = 2, b = 31, srep = 7, npref = 361
# repetition = 2, b = 31, srep = 8, npref = 361
# repetition = 2, b = 31, srep = 9, npref = 361
# Lex3 took 2.14
# repetition = 2, b = 32, srep = 0, npref = 380
# repetition = 2, b = 32, srep = 1, npref = 380
# repetition = 2, b = 32, srep = 2, npref = 380
# repetition = 2, b = 32, srep = 3, npref = 380
# repetition = 2, b = 32, srep = 4, npref = 380
# repetition = 2, b = 32, srep = 5, npref = 380
# repetition = 2, b = 32, srep = 6, npref = 380
# repetition = 2, b = 32, srep = 7, npref = 380
# repetition = 2, b = 32, srep = 8, npref = 380
# repetition = 2, b = 32, srep = 9, npref = 380
# Lex3 took 2.12
# repetition = 2, b = 33, srep = 0, npref = 403
# repetition = 2, b = 33, srep = 1, npref = 403
# repetition = 2, b = 33, srep = 2, npref = 403
# repetition = 2, b = 33, srep = 3, npref = 403
# repetition = 2, b = 33, srep = 4, npref = 403
# repetition = 2, b = 33, srep = 5, npref = 403
# repetition = 2, b = 33, srep = 6, npref = 403
# repetition = 2, b = 33, srep = 7, npref = 403
# repetition = 2, b = 33, srep = 8, npref = 403
# repetition = 2, b = 33, srep = 9, npref = 403
# Lex3 took 1.90
# repetition = 2, b = 34, srep = 0, npref = 432
# repetition = 2, b = 34, srep = 1, npref = 432
# repetition = 2, b = 34, srep = 2, npref = 432
# repetition = 2, b = 34, srep = 3, npref = 432
# repetition = 2, b = 34, srep = 4, npref = 432
# repetition = 2, b = 34, srep = 5, npref = 432
# repetition = 2, b = 34, srep = 6, npref = 432
# repetition = 2, b = 34, srep = 7, npref = 432
# repetition = 2, b = 34, srep = 8, npref = 432
# repetition = 2, b = 34, srep = 9, npref = 432
# Lex3 took 1.14
# repetition = 3, b = 5, srep = 0, npref = 13
# repetition = 3, b = 5, srep = 1, npref = 13
# repetition = 3, b = 5, srep = 2, npref = 13
# repetition = 3, b = 5, srep = 3, npref = 13
# repetition = 3, b = 5, srep = 4, npref = 13
# repetition = 3, b = 5, srep = 5, npref = 13
# repetition = 3, b = 5, srep = 6, npref = 13
# repetition = 3, b = 5, srep = 7, npref = 13
# repetition = 3, b = 5, srep = 8, npref = 13
# repetition = 3, b = 5, srep = 9, npref = 13
# Lex3 took 2.19
# repetition = 3, b = 6, srep = 0, npref = 19
# repetition = 3, b = 6, srep = 1, npref = 19
# repetition = 3, b = 6, srep = 2, npref = 19
# repetition = 3, b = 6, srep = 3, npref = 19
# repetition = 3, b = 6, srep = 4, npref = 19
# repetition = 3, b = 6, srep = 5, npref = 19
# repetition = 3, b = 6, srep = 6, npref = 19
# repetition = 3, b = 6, srep = 7, npref = 19
# repetition = 3, b = 6, srep = 8, npref = 19
# repetition = 3, b = 6, srep = 9, npref = 19
# Lex3 took 2.37
# repetition = 3, b = 7, srep = 0, npref = 24
# repetition = 3, b = 7, srep = 1, npref = 24
# repetition = 3, b = 7, srep = 2, npref = 24
# repetition = 3, b = 7, srep = 3, npref = 24
# repetition = 3, b = 7, srep = 4, npref = 24
# repetition = 3, b = 7, srep = 5, npref = 24
# repetition = 3, b = 7, srep = 6, npref = 24
# repetition = 3, b = 7, srep = 7, npref = 24
# repetition = 3, b = 7, srep = 8, npref = 24
# repetition = 3, b = 7, srep = 9, npref = 24
# Lex3 took 2.49
# repetition = 3, b = 8, srep = 0, npref = 30
# repetition = 3, b = 8, srep = 1, npref = 30
# repetition = 3, b = 8, srep = 2, npref = 30
# repetition = 3, b = 8, srep = 3, npref = 30
# repetition = 3, b = 8, srep = 4, npref = 30
# repetition = 3, b = 8, srep = 5, npref = 30
# repetition = 3, b = 8, srep = 6, npref = 30
# repetition = 3, b = 8, srep = 7, npref = 30
# repetition = 3, b = 8, srep = 8, npref = 30
# repetition = 3, b = 8, srep = 9, npref = 30
# Lex3 took 0.87
# repetition = 3, b = 9, srep = 0, npref = 36
# repetition = 3, b = 9, srep = 1, npref = 36
# repetition = 3, b = 9, srep = 2, npref = 36
# repetition = 3, b = 9, srep = 3, npref = 36
# repetition = 3, b = 9, srep = 4, npref = 36
# repetition = 3, b = 9, srep = 5, npref = 36
# repetition = 3, b = 9, srep = 6, npref = 36
# repetition = 3, b = 9, srep = 7, npref = 36
# repetition = 3, b = 9, srep = 8, npref = 36
# repetition = 3, b = 9, srep = 9, npref = 36
# Lex3 took 1.11
# repetition = 3, b = 10, srep = 0, npref = 45
# repetition = 3, b = 10, srep = 1, npref = 45
# repetition = 3, b = 10, srep = 2, npref = 45
# repetition = 3, b = 10, srep = 3, npref = 45
# repetition = 3, b = 10, srep = 4, npref = 45
# repetition = 3, b = 10, srep = 5, npref = 45
# repetition = 3, b = 10, srep = 6, npref = 45
# repetition = 3, b = 10, srep = 7, npref = 45
# repetition = 3, b = 10, srep = 8, npref = 45
# repetition = 3, b = 10, srep = 9, npref = 45
# Lex3 took 1.10
# repetition = 3, b = 11, srep = 0, npref = 54
# repetition = 3, b = 11, srep = 1, npref = 54
# repetition = 3, b = 11, srep = 2, npref = 54
# repetition = 3, b = 11, srep = 3, npref = 54
# repetition = 3, b = 11, srep = 4, npref = 54
# repetition = 3, b = 11, srep = 5, npref = 54
# repetition = 3, b = 11, srep = 6, npref = 54
# repetition = 3, b = 11, srep = 7, npref = 54
# repetition = 3, b = 11, srep = 8, npref = 54
# repetition = 3, b = 11, srep = 9, npref = 54
# Lex3 took 1.05
# repetition = 3, b = 12, srep = 0, npref = 63
# repetition = 3, b = 12, srep = 1, npref = 63
# repetition = 3, b = 12, srep = 2, npref = 63
# repetition = 3, b = 12, srep = 3, npref = 63
# repetition = 3, b = 12, srep = 4, npref = 63
# repetition = 3, b = 12, srep = 5, npref = 63
# repetition = 3, b = 12, srep = 6, npref = 63
# repetition = 3, b = 12, srep = 7, npref = 63
# repetition = 3, b = 12, srep = 8, npref = 63
# repetition = 3, b = 12, srep = 9, npref = 63
# Lex3 took 0.54
# repetition = 3, b = 13, srep = 0, npref = 72
# repetition = 3, b = 13, srep = 1, npref = 72
# repetition = 3, b = 13, srep = 2, npref = 72
# repetition = 3, b = 13, srep = 3, npref = 72
# repetition = 3, b = 13, srep = 4, npref = 72
# repetition = 3, b = 13, srep = 5, npref = 72
# repetition = 3, b = 13, srep = 6, npref = 72
# repetition = 3, b = 13, srep = 7, npref = 72
# repetition = 3, b = 13, srep = 8, npref = 72
# repetition = 3, b = 13, srep = 9, npref = 72
# Lex3 took 0.63
# repetition = 3, b = 14, srep = 0, npref = 83
# repetition = 3, b = 14, srep = 1, npref = 83
# repetition = 3, b = 14, srep = 2, npref = 83
# repetition = 3, b = 14, srep = 3, npref = 83
# repetition = 3, b = 14, srep = 4, npref = 83
# repetition = 3, b = 14, srep = 5, npref = 83
# repetition = 3, b = 14, srep = 6, npref = 83
# repetition = 3, b = 14, srep = 7, npref = 83
# repetition = 3, b = 14, srep = 8, npref = 83
# repetition = 3, b = 14, srep = 9, npref = 83
# Lex3 took 0.64
# repetition = 3, b = 15, srep = 0, npref = 93
# repetition = 3, b = 15, srep = 1, npref = 93
# repetition = 3, b = 15, srep = 2, npref = 93
# repetition = 3, b = 15, srep = 3, npref = 93
# repetition = 3, b = 15, srep = 4, npref = 93
# repetition = 3, b = 15, srep = 5, npref = 93
# repetition = 3, b = 15, srep = 6, npref = 93
# repetition = 3, b = 15, srep = 7, npref = 93
# repetition = 3, b = 15, srep = 8, npref = 93
# repetition = 3, b = 15, srep = 9, npref = 93
# Lex3 took 0.66
# repetition = 3, b = 16, srep = 0, npref = 105
# repetition = 3, b = 16, srep = 1, npref = 105
# repetition = 3, b = 16, srep = 2, npref = 105
# repetition = 3, b = 16, srep = 3, npref = 105
# repetition = 3, b = 16, srep = 4, npref = 105
# repetition = 3, b = 16, srep = 5, npref = 105
# repetition = 3, b = 16, srep = 6, npref = 105
# repetition = 3, b = 16, srep = 7, npref = 105
# repetition = 3, b = 16, srep = 8, npref = 105
# repetition = 3, b = 16, srep = 9, npref = 105
# Lex3 took 0.53
# repetition = 3, b = 17, srep = 0, npref = 121
# repetition = 3, b = 17, srep = 1, npref = 121
# repetition = 3, b = 17, srep = 2, npref = 121
# repetition = 3, b = 17, srep = 3, npref = 121
# ...
# repetition = 18, b = 30, srep = 8, npref = 332
# repetition = 18, b = 30, srep = 9, npref = 332
# Lex3 took 1.44
# repetition = 18, b = 31, srep = 0, npref = 351
# repetition = 18, b = 31, srep = 1, npref = 351
# repetition = 18, b = 31, srep = 2, npref = 351
# repetition = 18, b = 31, srep = 3, npref = 351
# repetition = 18, b = 31, srep = 4, npref = 351
# repetition = 18, b = 31, srep = 5, npref = 351
# repetition = 18, b = 31, srep = 6, npref = 351
# repetition = 18, b = 31, srep = 7, npref = 351
# repetition = 18, b = 31, srep = 8, npref = 351
# repetition = 18, b = 31, srep = 9, npref = 351
# Lex3 took 1.58
# repetition = 18, b = 32, srep = 0, npref = 373
# repetition = 18, b = 32, srep = 1, npref = 373
# repetition = 18, b = 32, srep = 2, npref = 373
# repetition = 18, b = 32, srep = 3, npref = 373
# repetition = 18, b = 32, srep = 4, npref = 373
# repetition = 18, b = 32, srep = 5, npref = 373
# repetition = 18, b = 32, srep = 6, npref = 373
# repetition = 18, b = 32, srep = 7, npref = 373
# repetition = 18, b = 32, srep = 8, npref = 373
# repetition = 18, b = 32, srep = 9, npref = 373
# Lex3 took 1.64
# repetition = 18, b = 33, srep = 0, npref = 393
# repetition = 18, b = 33, srep = 1, npref = 393
# repetition = 18, b = 33, srep = 2, npref = 393
# repetition = 18, b = 33, srep = 3, npref = 393
# repetition = 18, b = 33, srep = 4, npref = 393
# repetition = 18, b = 33, srep = 5, npref = 393
# repetition = 18, b = 33, srep = 6, npref = 393
# repetition = 18, b = 33, srep = 7, npref = 393
# repetition = 18, b = 33, srep = 8, npref = 393
# repetition = 18, b = 33, srep = 9, npref = 393
# Lex3 took 1.58
# repetition = 18, b = 34, srep = 0, npref = 413
# repetition = 18, b = 34, srep = 1, npref = 413
# repetition = 18, b = 34, srep = 2, npref = 413
# repetition = 18, b = 34, srep = 3, npref = 413
# repetition = 18, b = 34, srep = 4, npref = 413
# repetition = 18, b = 34, srep = 5, npref = 413
# repetition = 18, b = 34, srep = 6, npref = 413
# repetition = 18, b = 34, srep = 7, npref = 413
# repetition = 18, b = 34, srep = 8, npref = 413
# repetition = 18, b = 34, srep = 9, npref = 413
# Lex3 took 1.02
# repetition = 19, b = 6, srep = 0, npref = 11
# repetition = 19, b = 6, srep = 1, npref = 11
# repetition = 19, b = 6, srep = 2, npref = 11
# repetition = 19, b = 6, srep = 3, npref = 11
# repetition = 19, b = 6, srep = 4, npref = 11
# repetition = 19, b = 6, srep = 5, npref = 11
# repetition = 19, b = 6, srep = 6, npref = 11
# repetition = 19, b = 6, srep = 7, npref = 11
# repetition = 19, b = 6, srep = 8, npref = 11
# repetition = 19, b = 6, srep = 9, npref = 11
# Lex3 took 2.22
# repetition = 19, b = 7, srep = 0, npref = 18
# repetition = 19, b = 7, srep = 1, npref = 18
# repetition = 19, b = 7, srep = 2, npref = 18
# repetition = 19, b = 7, srep = 3, npref = 18
# repetition = 19, b = 7, srep = 4, npref = 18
# repetition = 19, b = 7, srep = 5, npref = 18
# repetition = 19, b = 7, srep = 6, npref = 18
# repetition = 19, b = 7, srep = 7, npref = 18
# repetition = 19, b = 7, srep = 8, npref = 18
# repetition = 19, b = 7, srep = 9, npref = 18
# Lex3 took 0.30
# repetition = 19, b = 8, srep = 0, npref = 26
# repetition = 19, b = 8, srep = 1, npref = 26
# repetition = 19, b = 8, srep = 2, npref = 26
# repetition = 19, b = 8, srep = 3, npref = 26
# repetition = 19, b = 8, srep = 4, npref = 26
# repetition = 19, b = 8, srep = 5, npref = 26
# repetition = 19, b = 8, srep = 6, npref = 26
# repetition = 19, b = 8, srep = 7, npref = 26
# repetition = 19, b = 8, srep = 8, npref = 26
# repetition = 19, b = 8, srep = 9, npref = 26
# Lex3 took 0.31
# repetition = 19, b = 9, srep = 0, npref = 30
# repetition = 19, b = 9, srep = 1, npref = 30
# repetition = 19, b = 9, srep = 2, npref = 30
# repetition = 19, b = 9, srep = 3, npref = 30
# repetition = 19, b = 9, srep = 4, npref = 30
# repetition = 19, b = 9, srep = 5, npref = 30
# repetition = 19, b = 9, srep = 6, npref = 30
# repetition = 19, b = 9, srep = 7, npref = 30
# repetition = 19, b = 9, srep = 8, npref = 30
# repetition = 19, b = 9, srep = 9, npref = 30
# Lex3 took 0.36
# repetition = 19, b = 10, srep = 0, npref = 34
# repetition = 19, b = 10, srep = 1, npref = 34
# repetition = 19, b = 10, srep = 2, npref = 34
# repetition = 19, b = 10, srep = 3, npref = 34
# repetition = 19, b = 10, srep = 4, npref = 34
# repetition = 19, b = 10, srep = 5, npref = 34
# repetition = 19, b = 10, srep = 6, npref = 34
# repetition = 19, b = 10, srep = 7, npref = 34
# repetition = 19, b = 10, srep = 8, npref = 34
# repetition = 19, b = 10, srep = 9, npref = 34
# Lex3 took 0.36
# repetition = 19, b = 11, srep = 0, npref = 44
# repetition = 19, b = 11, srep = 1, npref = 44
# repetition = 19, b = 11, srep = 2, npref = 44
# repetition = 19, b = 11, srep = 3, npref = 44
# repetition = 19, b = 11, srep = 4, npref = 44
# repetition = 19, b = 11, srep = 5, npref = 44
# repetition = 19, b = 11, srep = 6, npref = 44
# repetition = 19, b = 11, srep = 7, npref = 44
# repetition = 19, b = 11, srep = 8, npref = 44
# repetition = 19, b = 11, srep = 9, npref = 44
# Lex3 took 0.34
# repetition = 19, b = 12, srep = 0, npref = 55
# repetition = 19, b = 12, srep = 1, npref = 55
# repetition = 19, b = 12, srep = 2, npref = 55
# repetition = 19, b = 12, srep = 3, npref = 55
# repetition = 19, b = 12, srep = 4, npref = 55
# repetition = 19, b = 12, srep = 5, npref = 55
# repetition = 19, b = 12, srep = 6, npref = 55
# repetition = 19, b = 12, srep = 7, npref = 55
# repetition = 19, b = 12, srep = 8, npref = 55
# repetition = 19, b = 12, srep = 9, npref = 55
# Lex3 took 0.38
# repetition = 19, b = 13, srep = 0, npref = 66
# repetition = 19, b = 13, srep = 1, npref = 66
# repetition = 19, b = 13, srep = 2, npref = 66
# repetition = 19, b = 13, srep = 3, npref = 66
# repetition = 19, b = 13, srep = 4, npref = 66
# repetition = 19, b = 13, srep = 5, npref = 66
# repetition = 19, b = 13, srep = 6, npref = 66
# repetition = 19, b = 13, srep = 7, npref = 66
# repetition = 19, b = 13, srep = 8, npref = 66
# repetition = 19, b = 13, srep = 9, npref = 66
# Lex3 took 0.38
# repetition = 19, b = 14, srep = 0, npref = 77
# repetition = 19, b = 14, srep = 1, npref = 77
# repetition = 19, b = 14, srep = 2, npref = 77
# repetition = 19, b = 14, srep = 3, npref = 77
# repetition = 19, b = 14, srep = 4, npref = 77
# repetition = 19, b = 14, srep = 5, npref = 77
# repetition = 19, b = 14, srep = 6, npref = 77
# repetition = 19, b = 14, srep = 7, npref = 77
# repetition = 19, b = 14, srep = 8, npref = 77
# repetition = 19, b = 14, srep = 9, npref = 77
# Lex3 took 0.45
# repetition = 19, b = 15, srep = 0, npref = 91
# repetition = 19, b = 15, srep = 1, npref = 91
# repetition = 19, b = 15, srep = 2, npref = 91
# repetition = 19, b = 15, srep = 3, npref = 91
# repetition = 19, b = 15, srep = 4, npref = 91
# repetition = 19, b = 15, srep = 5, npref = 91
# repetition = 19, b = 15, srep = 6, npref = 91
# repetition = 19, b = 15, srep = 7, npref = 91
# repetition = 19, b = 15, srep = 8, npref = 91
# repetition = 19, b = 15, srep = 9, npref = 91
# Lex3 took 0.41
# repetition = 19, b = 16, srep = 0, npref = 103
# repetition = 19, b = 16, srep = 1, npref = 103
# repetition = 19, b = 16, srep = 2, npref = 103
# repetition = 19, b = 16, srep = 3, npref = 103
# repetition = 19, b = 16, srep = 4, npref = 103
# repetition = 19, b = 16, srep = 5, npref = 103
# repetition = 19, b = 16, srep = 6, npref = 103
# repetition = 19, b = 16, srep = 7, npref = 103
# repetition = 19, b = 16, srep = 8, npref = 103
# repetition = 19, b = 16, srep = 9, npref = 103
# Lex3 took 0.67
# repetition = 19, b = 17, srep = 0, npref = 118
# repetition = 19, b = 17, srep = 1, npref = 118
# repetition = 19, b = 17, srep = 2, npref = 118
# repetition = 19, b = 17, srep = 3, npref = 118
# repetition = 19, b = 17, srep = 4, npref = 118
# repetition = 19, b = 17, srep = 5, npref = 118
# repetition = 19, b = 17, srep = 6, npref = 118
# repetition = 19, b = 17, srep = 7, npref = 118
# repetition = 19, b = 17, srep = 8, npref = 118
# repetition = 19, b = 17, srep = 9, npref = 118
# Lex3 took 0.62
# repetition = 19, b = 18, srep = 0, npref = 133
# repetition = 19, b = 18, srep = 1, npref = 133
# repetition = 19, b = 18, srep = 2, npref = 133
# repetition = 19, b = 18, srep = 3, npref = 133
# repetition = 19, b = 18, srep = 4, npref = 133
# repetition = 19, b = 18, srep = 5, npref = 133
# repetition = 19, b = 18, srep = 6, npref = 133
# repetition = 19, b = 18, srep = 7, npref = 133
# repetition = 19, b = 18, srep = 8, npref = 133
# repetition = 19, b = 18, srep = 9, npref = 133
# Lex3 took 1.23
# repetition = 19, b = 19, srep = 0, npref = 148
# repetition = 19, b = 19, srep = 1, npref = 148
# repetition = 19, b = 19, srep = 2, npref = 148
# repetition = 19, b = 19, srep = 3, npref = 148
# repetition = 19, b = 19, srep = 4, npref = 148
# repetition = 19, b = 19, srep = 5, npref = 148
# repetition = 19, b = 19, srep = 6, npref = 148
# repetition = 19, b = 19, srep = 7, npref = 148
# repetition = 19, b = 19, srep = 8, npref = 148
# repetition = 19, b = 19, srep = 9, npref = 148
# Lex3 took 1.14
# repetition = 19, b = 20, srep = 0, npref = 161
# repetition = 19, b = 20, srep = 1, npref = 161
# repetition = 19, b = 20, srep = 2, npref = 161
# repetition = 19, b = 20, srep = 3, npref = 161
# repetition = 19, b = 20, srep = 4, npref = 161
# repetition = 19, b = 20, srep = 5, npref = 161
# repetition = 19, b = 20, srep = 6, npref = 161
# repetition = 19, b = 20, srep = 7, npref = 161
# repetition = 19, b = 20, srep = 8, npref = 161
# repetition = 19, b = 20, srep = 9, npref = 161
# Lex3 took 1.24
# repetition = 19, b = 21, srep = 0, npref = 174
# repetition = 19, b = 21, srep = 1, npref = 174
# repetition = 19, b = 21, srep = 2, npref = 174
# repetition = 19, b = 21, srep = 3, npref = 174
# repetition = 19, b = 21, srep = 4, npref = 174
# repetition = 19, b = 21, srep = 5, npref = 174
# repetition = 19, b = 21, srep = 6, npref = 174
# repetition = 19, b = 21, srep = 7, npref = 174
# repetition = 19, b = 21, srep = 8, npref = 174
# repetition = 19, b = 21, srep = 9, npref = 174
# Lex3 took 1.05
# repetition = 19, b = 22, srep = 0, npref = 187
# repetition = 19, b = 22, srep = 1, npref = 187
# repetition = 19, b = 22, srep = 2, npref = 187
# repetition = 19, b = 22, srep = 3, npref = 187
# repetition = 19, b = 22, srep = 4, npref = 187
# repetition = 19, b = 22, srep = 5, npref = 187
# repetition = 19, b = 22, srep = 6, npref = 187
# repetition = 19, b = 22, srep = 7, npref = 187
# repetition = 19, b = 22, srep = 8, npref = 187
# repetition = 19, b = 22, srep = 9, npref = 187
# Lex3 took 0.99
# repetition = 19, b = 23, srep = 0, npref = 200
# repetition = 19, b = 23, srep = 1, npref = 200
# repetition = 19, b = 23, srep = 2, npref = 200
# repetition = 19, b = 23, srep = 3, npref = 200
# repetition = 19, b = 23, srep = 4, npref = 200
# repetition = 19, b = 23, srep = 5, npref = 200
# repetition = 19, b = 23, srep = 6, npref = 200
# repetition = 19, b = 23, srep = 7, npref = 200
# repetition = 19, b = 23, srep = 8, npref = 200
# repetition = 19, b = 23, srep = 9, npref = 200
# Lex3 took 1.05
# repetition = 19, b = 24, srep = 0, npref = 213
# repetition = 19, b = 24, srep = 1, npref = 213
# repetition = 19, b = 24, srep = 2, npref = 213
# repetition = 19, b = 24, srep = 3, npref = 213
# repetition = 19, b = 24, srep = 4, npref = 213
# repetition = 19, b = 24, srep = 5, npref = 213
# repetition = 19, b = 24, srep = 6, npref = 213
# repetition = 19, b = 24, srep = 7, npref = 213
# repetition = 19, b = 24, srep = 8, npref = 213
# repetition = 19, b = 24, srep = 9, npref = 213
# Lex3 took 1.08
# repetition = 19, b = 25, srep = 0, npref = 226
# repetition = 19, b = 25, srep = 1, npref = 226
# repetition = 19, b = 25, srep = 2, npref = 226
# repetition = 19, b = 25, srep = 3, npref = 226
# repetition = 19, b = 25, srep = 4, npref = 226
# repetition = 19, b = 25, srep = 5, npref = 226
# repetition = 19, b = 25, srep = 6, npref = 226
# repetition = 19, b = 25, srep = 7, npref = 226
# repetition = 19, b = 25, srep = 8, npref = 226
# repetition = 19, b = 25, srep = 9, npref = 226
# Lex3 took 1.29
# repetition = 19, b = 26, srep = 0, npref = 251
# repetition = 19, b = 26, srep = 1, npref = 251
# repetition = 19, b = 26, srep = 2, npref = 251
# repetition = 19, b = 26, srep = 3, npref = 251
# repetition = 19, b = 26, srep = 4, npref = 251
# repetition = 19, b = 26, srep = 5, npref = 251
# repetition = 19, b = 26, srep = 6, npref = 251
# repetition = 19, b = 26, srep = 7, npref = 251
# repetition = 19, b = 26, srep = 8, npref = 251
# repetition = 19, b = 26, srep = 9, npref = 251
# Lex3 took 1.20
# repetition = 19, b = 27, srep = 0, npref = 265
# repetition = 19, b = 27, srep = 1, npref = 265
# repetition = 19, b = 27, srep = 2, npref = 265
# repetition = 19, b = 27, srep = 3, npref = 265
# repetition = 19, b = 27, srep = 4, npref = 265
# repetition = 19, b = 27, srep = 5, npref = 265
# repetition = 19, b = 27, srep = 6, npref = 265
# repetition = 19, b = 27, srep = 7, npref = 265
# repetition = 19, b = 27, srep = 8, npref = 265
# repetition = 19, b = 27, srep = 9, npref = 265
# Lex3 took 1.21
# repetition = 19, b = 28, srep = 0, npref = 288
# repetition = 19, b = 28, srep = 1, npref = 288
# repetition = 19, b = 28, srep = 2, npref = 288
# repetition = 19, b = 28, srep = 3, npref = 288
# repetition = 19, b = 28, srep = 4, npref = 288
# repetition = 19, b = 28, srep = 5, npref = 288
# repetition = 19, b = 28, srep = 6, npref = 288
# repetition = 19, b = 28, srep = 7, npref = 288
# repetition = 19, b = 28, srep = 8, npref = 288
# repetition = 19, b = 28, srep = 9, npref = 288
# Lex3 took 1.29
# repetition = 19, b = 29, srep = 0, npref = 311
# repetition = 19, b = 29, srep = 1, npref = 311
# repetition = 19, b = 29, srep = 2, npref = 311
# repetition = 19, b = 29, srep = 3, npref = 311
# repetition = 19, b = 29, srep = 4, npref = 311
# repetition = 19, b = 29, srep = 5, npref = 311
# repetition = 19, b = 29, srep = 6, npref = 311
# repetition = 19, b = 29, srep = 7, npref = 311
# repetition = 19, b = 29, srep = 8, npref = 311
# repetition = 19, b = 29, srep = 9, npref = 311
# Lex3 took 1.19
# repetition = 19, b = 30, srep = 0, npref = 339
# repetition = 19, b = 30, srep = 1, npref = 339
# repetition = 19, b = 30, srep = 2, npref = 339
# repetition = 19, b = 30, srep = 3, npref = 339
# repetition = 19, b = 30, srep = 4, npref = 339
# repetition = 19, b = 30, srep = 5, npref = 339
# repetition = 19, b = 30, srep = 6, npref = 339
# repetition = 19, b = 30, srep = 7, npref = 339
# repetition = 19, b = 30, srep = 8, npref = 339
# repetition = 19, b = 30, srep = 9, npref = 339
# Lex3 took 3.06
# repetition = 19, b = 31, srep = 0, npref = 368
# repetition = 19, b = 31, srep = 1, npref = 368
# repetition = 19, b = 31, srep = 2, npref = 368
# repetition = 19, b = 31, srep = 3, npref = 368
# repetition = 19, b = 31, srep = 4, npref = 368
# repetition = 19, b = 31, srep = 5, npref = 368
# repetition = 19, b = 31, srep = 6, npref = 368
# repetition = 19, b = 31, srep = 7, npref = 368
# repetition = 19, b = 31, srep = 8, npref = 368
# repetition = 19, b = 31, srep = 9, npref = 368
# Lex3 took 2.74
# repetition = 19, b = 32, srep = 0, npref = 393
# repetition = 19, b = 32, srep = 1, npref = 393
# repetition = 19, b = 32, srep = 2, npref = 393
# repetition = 19, b = 32, srep = 3, npref = 393
# repetition = 19, b = 32, srep = 4, npref = 393
# repetition = 19, b = 32, srep = 5, npref = 393
# repetition = 19, b = 32, srep = 6, npref = 393
# repetition = 19, b = 32, srep = 7, npref = 393
# repetition = 19, b = 32, srep = 8, npref = 393
# repetition = 19, b = 32, srep = 9, npref = 393
# Lex3 took 2.24
# repetition = 19, b = 33, srep = 0, npref = 412
# repetition = 19, b = 33, srep = 1, npref = 412
# repetition = 19, b = 33, srep = 2, npref = 412
# repetition = 19, b = 33, srep = 3, npref = 412
# repetition = 19, b = 33, srep = 4, npref = 412
# repetition = 19, b = 33, srep = 5, npref = 412
# repetition = 19, b = 33, srep = 6, npref = 412
# repetition = 19, b = 33, srep = 7, npref = 412
# repetition = 19, b = 33, srep = 8, npref = 412
# repetition = 19, b = 33, srep = 9, npref = 412
# Lex3 took 2.63
# repetition = 19, b = 34, srep = 0, npref = 431
# repetition = 19, b = 34, srep = 1, npref = 431
# repetition = 19, b = 34, srep = 2, npref = 431
# repetition = 19, b = 34, srep = 3, npref = 431
# repetition = 19, b = 34, srep = 4, npref = 431
# repetition = 19, b = 34, srep = 5, npref = 431
# repetition = 19, b = 34, srep = 6, npref = 431
# repetition = 19, b = 34, srep = 7, npref = 431
# repetition = 19, b = 34, srep = 8, npref = 431
# repetition = 19, b = 34, srep = 9, npref = 431
