# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("theta_comparisons_3.csv")
df["ACR"] = df["C"] / df["T"]
df
# Out:
#      Unnamed: 0  budget       theta  n_theta_min  n_preferences  additivity  \
# 0             0       1   heuristic            1              1           2
# 1             1       1      random            1              1           1
# 2             2       1       union            1              1           1
# 3             3       1  all_thetas            1              1           1
# 4             4       1   heuristic            1              1           3
# ..          ...     ...         ...          ...            ...         ...
# 575         575       5  all_thetas            1            318           4
# 576         576       5   heuristic            1            318           4
# 577         577       5      random            1            318           4
# 578         578       5       union            1            318           4
# 579         579       5  all_thetas            1            318           4
#
#      size  sizes_sum   C  W   T       ACR
# ...

# %%
sns.lineplot(x = "budget", y = "ACR", hue = "theta", data = df)
# Out:
# <AxesSubplot:xlabel='budget', ylabel='ACR'>

# %%
sns.lineplot(x = "budget", y = "T", hue = "theta", data = df)
# Out:
# <AxesSubplot:xlabel='budget', ylabel='T'>

# %%
sns.lineplot(x = "n_preferences", y = "ACR", hue = "theta", data = df)
# Out:
# <AxesSubplot:xlabel='n_preferences', ylabel='ACR'>

# %%
sns.lineplot(x = "n_preferences", y = "T", hue = "theta", data = df)
# Out:
# <AxesSubplot:xlabel='n_preferences', ylabel='T'>

# %%
df = pd.read_csv("theta_definitions_comparisons_3.csv")
df["ACR"] = df["C"] / df["T"]
df
# Out:
#        Unnamed: 0  budget theta_definition theta_operator  n_theta_min  \
# 0               0       1             LEX2          UNION            2
# 1               1       1             LEX2            RND            2
# 2               2       1             LEX2            ALL            2
# 3               3       1             LEX3          UNION            2
# 4               4       1             LEX3            RND            2
# ...           ...     ...              ...            ...          ...
# 12145       12145      17             LEX3            RND            1
# 12146       12146      17             LEX3            ALL            1
# 12147       12147      17              VAR          UNION            2
# 12148       12148      17              VAR            RND            2
# 12149       12149      17              VAR            ALL            2
#
#        n_preferences  additivity  size  sizes_sum      time  C  W  T       ACR
# ...
