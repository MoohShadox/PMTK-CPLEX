# %%
import pandas as pd
import numpy as np
from collections import Counter
import time
from PMTK.sampling.preferences_sampler import *
from PMTK.pref.preferences import *
from PMTK.utility.utility_solver import *
from PMTK.sampling.subset_samplers import *
from PMTK.utility.subset_finder import *
from PMTK.sampling.gibbs import *
from PMTK.data.film_dataset import *
from PMTK.sampling.decider import *
from PMTK.utility import *
from itertools import combinations
from sklearn import svm

def build_approx_theta(prf, init_theta = None):
    connivents = []
    if not init_theta:
        init_theta = [EMPTY_SET]
    theta = init_theta
    min_k = 1
    c  = get_connivent(theta, prf)
    cpt = 0
    while c:
        if not c in connivents:
            connivents.append(c)
        cit = get_candidate_iterator(c)
        skey = sorted(cit.keys())[0]
        b = False
        for k in cit:
            if b:
                break
            for i in cit[k]:
                s = set(i)
                for t in s:
                    b = b or (check_connivence_resolution(c, t) and not t in theta)
                    if not t in theta and check_connivence_resolution(c, t):
                        theta.append(t)
        c  = get_connivent(theta, prf)
        cpt = cpt + 1
        #print("solved connivent: ", cpt, " with", theta)
    a = additivity(theta)
    for c_i in connivents:
        cit = get_candidate_iterator(c_i)
        for k in cit:
            if k > a:
                break
            for i in cit[k]:
                for t in i:
                    if not t in theta and check_connivence_resolution(c_i,t):
                        theta.append(t)
    
    return theta

# %%
n_items = 6
items = np.arange(n_items)
ground_truth = Tierlist_Decider(items, p=0.3, alpha = 0.3)
decider = Objective_Function(items, ground_truth)

subsets = sample_subsets(items, n_subsets=10)
for s in subsets:
    decider(s)
    
prf = decider.relation()
theta = build_approx_theta(prf)

# %%
def train_cardinal_model(prf ,theta):
    mdl = utility_polyhedron(prf.items, theta, prf)
    mdl.maximize(-mdl.slack_sum)
    mdl.solve()
    d = {t : mdl.utilities[t].solution_value for t in mdl.utilities if mdl.utilities[t].solution_value != 0}
    return d

def evaluate_cardinal_model(cardinal_model, subset):
    s = 0
    for x in cardinal_model:
        if all(i in subset for i in x):
            s += cardinal_model[x]
    return s
        
        
def predict_cardinal(cardinal_model, items, subsets):
    prf = Preferences(items)
    for i_1 in range(len(subsets)):
        s_1 = subsets[i_1]
        e_1 = evaluate_cardinal_model(cardinal_model, s_1)
        for i_2 in range(i_1 + 1, len(subsets)):
            s_2 = subsets[i_2]
            e_2 = evaluate_cardinal_model(cardinal_model, s_2)
            if e_1 > e_2:
                prf.add_preference(s_1, s_2)
            if e_2 > e_1:
                prf.add_preference(s_2, s_1)
            if e_1 == e_2:
                prf.add_indifference(s_1, s_2)
    return prf


def train_svm_model(prf, theta, clf = None):
    if not clf:
        clf = svm.SVC()
    L = []
    for x,y in prf.preferred:
        v_x = list(vectorize_subset(x, theta))
        v_y = list(vectorize_subset(y, theta))
        L.append(np.array(v_x + v_y + [1]))
        L.append(np.array(v_y + v_x + [0]))
    data = np.array(L)
    X,y = data[:, :-1], data[:, -1]
    clf.fit(X,y)
    return clf

def predict_svm(svm_model,items, subsets, theta):
    prf = Preferences(items)
    for i_x in range(len(subsets)):
        x = subsets[i_x]
        for i_y in range(i_x+1, len(subsets)):
            y = subsets[i_y]
            v_x = list(vectorize_subset(x, theta))
            v_y = list(vectorize_subset(y, theta))
            v = np.array(v_x + v_y).reshape((1,-1))
            vi = np.array(v_y + v_x).reshape((1,-1))
            c = svm_model.predict(v)[0]
            ci = svm_model.predict(vi)[0]
            if c == 1 and ci == 0:
                prf.add_preference(x,y)
            if c == 0 and ci == 1:
                prf.add_preference(y,x)
    return prf

# %%
def build_approx_theta(prf, init_theta = None):
    connivents = []
    if not init_theta:
        init_theta = [EMPTY_SET]
    theta = init_theta
    min_k = 1
    c  = get_connivent(theta, prf)
    cpt = 0
    while c:
        if not c in connivents:
            connivents.append(c)
        cit = get_candidate_iterator(c)
        skey = sorted(cit.keys())[0]
        b = False
        for k in cit:
            if b:
                break
            for i in cit[k]:
                s = set(i)
                for t in s:
                    b = b or (check_connivence_resolution(c, t) and not t in theta)
                    if not t in theta and check_connivence_resolution(c, t):
                        theta.append(t)
        c  = get_connivent(theta, prf)
        cpt = cpt + 1
        print("solved connivent: ", cpt, " with", theta)
    a = additivity(theta)
    for c_i in connivents:
        cit = get_candidate_iterator(c_i)
        for k in cit:
            if k > a:
                break
            for i in cit[k]:
                for t in i:
                    if not t in theta and check_connivence_resolution(c_i,t):
                        theta.append(t)
    
    return theta

def predict_from_mult_thetas(thetas,p, subsets):
    mdls = [utility_polyhedron(p.items, t, p) for t in thetas]
    prf = Preferences(p.items)
    for i_1 in range(len(subsets)):
        s_1 = subsets[i_1]
        for i_2 in range(i_1 + 1, len(subsets)):
            s_2 = subsets[i_2]
            r = [ordinal_dominance(s_1, s_2, mdl) for mdl in mdls]
            if all(i == "SUP" for i in r):
                prf.add_preference(s_1, s_2)
            elif all(i == "INF" for i in r):
                prf.add_preference(s_2, s_1)
            elif all(i == "EQ" for i in r):
                prf.add_indifference(s_1,s_2)
    return prf

def predict_from_theta(theta, p, subsets):
    mdl = utility_polyhedron(p.items, theta, p)
    prf = ordinal_peferences(p.items, subsets, mdl)
    return prf

def ACR(prf, decider):
    C = 0
    W = 0
    T = len(prf.preferred)
    for x,y in prf.preferred:
        if decider(x) > decider(y):
            C += 1
        elif decider(x) < decider(y):
            W += 1
    return C,W,T

def intersect_per_union(prf_1, prf_2):
    intersection = prf_1.intersection(prf_2)
    un = prf_1 + prf_2
    return len(intersection) / len(un)

# %%
n_items = 5
items = np.arange(n_items)
ground_truth = Tierlist_Decider(items, p=0.3, alpha = 0.3)
decider = Objective_Function(items, ground_truth)

budget = 25
n_subsets = 10

data = {
    "budget":[],
    "theta_definition":[],
    "theta_operator":[],
    "n_theta_min":[],
    "n_preferences":[],
    "additivity":[],
    "size":[],
    "sizes_sum":[],
    "time":[],
    "C":[],
    "W":[],
    "T":[],
}


for repetition in range(10):
    ground_truth = Tierlist_Decider(items, p=0.3, alpha = 0.3)
    decider = Objective_Function(items, ground_truth)

    for b in range(budget):
        s = sample_subset(items)
        while s in decider.saved:
            s = sample_subset(items)
            
        decider(s)
        prf = decider.relation()
        if len(prf) < 5:
            continue
            
        t_heuristic = build_approx_theta(prf, [EMPTY_SET])
            
        ti_lex_2 = time.time()
        t_lex2 = get_kernels_lex2(prf, get_all_k_sets(items, len(items)))
        ti_lex_2 = time.time() - ti_lex_2
        
        t_lex2_rnd = random.choice(t_lex2)
        t_lex2_union = union(t_lex2)
        
        
        ti_lex_3 = time.time()
        t_lex3 = get_kernels_lex3(prf, get_all_k_sets(items, len(items)))
        ti_lex_3 = time.time() - ti_lex_3
        
        t_lex3_rnd = random.choice(t_lex3)
        t_lex3_union = union(t_lex3)
        
        
        ti_var = time.time()
        t_var = get_kernels_var(prf, get_all_k_sets(items, len(items)))
        ti_var = time.time() - ti_var
        
        t_var_rnd = random.choice(t_var)
        t_var_union = union(t_var)
        
        print(f"Lex2 took {ti_lex_2:.2f}")
        print(f"Lex3 took {ti_lex_3:.2f}")
        print(f"Var took {ti_var:.2f}")


        for s_rep in range(10):
            print(f"repetition = {repetition}, b = {b}, srep = {s_rep}, npref = {len(prf)}")
            test_subsets = sample_subsets(items, n_subsets=n_subsets)
            
            

            #print(f"t_union = {t_union}, t_heuristic = {t_heuristic}, t_mins = {t_mins}, t_random = {t_random}")
            
            prf_t_heuristic = predict_from_theta(t_heuristic, prf, test_subsets)

            
            prf_tlex2_union = predict_from_theta(t_lex2_union, prf, test_subsets)
            prf_tlex2_rnd = predict_from_theta(t_lex2_rnd, prf, test_subsets)
            prf_tlex2_all = predict_from_mult_thetas(t_lex2, prf, test_subsets)
            
            svm_tlex2 = train_svm_model(prf, t_lex2_union, clf = None)
            prf_svm_tlex2 = predict_svm(svm_tlex2,prf.items, test_subsets, t_lex2_union)
            
            card_tlex2 = train_cardinal_model(prf ,t_lex2_union)
            prf_card_tlex2 = predict_cardinal(card_tlex2, items, test_subsets)
            
            
            
            
            prf_tlex3_union = predict_from_theta(t_lex3_union, prf, test_subsets)
            prf_tlex3_rnd = predict_from_theta(t_lex3_rnd, prf, test_subsets)
            prf_tlex3_all = predict_from_mult_thetas(t_lex3, prf, test_subsets)
            
            svm_tlex3 = train_svm_model(prf, t_lex3_union, clf = None)
            prf_svm_tlex3 = predict_svm(svm_tlex3,prf.items, test_subsets, t_lex3_union)
            
            card_tlex3 = train_cardinal_model(prf ,t_lex3_union)
            prf_card_tlex3 = predict_cardinal(card_tlex3, items, test_subsets)
            
            
            
            
            
            prf_var_union = predict_from_theta(t_var_union, prf, test_subsets)
            prf_var_rnd = predict_from_theta(t_var_rnd, prf, test_subsets)
            prf_var_all = predict_from_mult_thetas(t_var[:10], prf, test_subsets)
            
            svm_var = train_svm_model(prf, t_var_union, clf = None)
            prf_svm_var = predict_svm(svm_var ,prf.items, test_subsets, t_var_union)
            
            card_var = train_cardinal_model(prf ,t_var_union)
            prf_card_var = predict_cardinal(card_var, items, test_subsets)
            
            
            
            
            C_t_heuristic, W_t_heuritistic, T_t_heuristic = ACR(prf_t_heuristic, ground_truth)
            
            C_tlex2_union, W_tlex2_union, T_tlex2_union = ACR(prf_tlex2_union, ground_truth)
            C_tlex2_rnd, W_tlex2_rnd, T_tlex2_rnd = ACR(prf_tlex2_rnd, ground_truth)
            C_tlex2_all, W_tlex2_all, T_tlex2_all = ACR(prf_tlex2_all, ground_truth)
            C_svm_tlex2, W_svm_tlex2, T_svm_tlex2 = ACR(prf_svm_tlex2, ground_truth)
            C_card_tlex2, W_card_tlex2, T_card_tlex2 = ACR(prf_card_tlex2, ground_truth)

            
            C_tlex3_union, W_tlex3_union, T_tlex3_union = ACR(prf_tlex3_union, ground_truth)
            C_tlex3_rnd, W_tlex3_rnd, T_tlex3_rnd = ACR(prf_tlex3_rnd, ground_truth)
            C_tlex3_all, W_tlex3_all, T_tlex3_all = ACR(prf_tlex3_all, ground_truth)
            C_svm_tlex3, W_svm_tlex3, T_svm_tlex3 = ACR(prf_svm_tlex3, ground_truth)
            C_card_tlex3, W_card_tlex3, T_card_tlex3 = ACR(prf_card_tlex3, ground_truth)

            
            C_var_union, W_var_union, T_var_union = ACR(prf_var_union, ground_truth)
            C_var_rnd, W_var_rnd, T_var_rnd = ACR(prf_var_rnd, ground_truth)
            C_var_all, W_var_all, T_var_all = ACR(prf_var_all, ground_truth)
            C_svm_var, W_svm_var, T_svm_var = ACR(prf_svm_var, ground_truth)
            C_card_var, W_card_var, T_card_var = ACR(prf_card_var, ground_truth)

            ###LEX 2
            data["budget"].append(b) 
            data["theta_definition"].append("LEX2")
            data["theta_operator"].append("UNION")
            data["time"].append(ti_lex_2)
            data["n_theta_min"].append(len(t_lex2))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex2_union))
            data["size"].append(len(t_lex2_union))
            data["sizes_sum"].append(sum(len(i) for i in t_lex2_union))
            data["C"].append(C_tlex2_union)
            data["W"].append(W_tlex2_union)
            data["T"].append(T_tlex2_union)
            
            data["budget"].append(b) 
            data["theta_definition"].append("LEX2")
            data["theta_operator"].append("RND")
            data["time"].append(ti_lex_2)
            data["n_theta_min"].append(len(t_lex2))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex2_rnd))
            data["size"].append(len(t_lex2_rnd))
            data["sizes_sum"].append(sum(len(i) for i in t_lex2_rnd))
            data["C"].append(C_tlex2_rnd)
            data["W"].append(W_tlex2_rnd)
            data["T"].append(T_tlex2_rnd)
            
            data["budget"].append(b) 
            data["theta_definition"].append("LEX2")
            data["theta_operator"].append("ALL")
            data["time"].append(ti_lex_2)
            data["n_theta_min"].append(len(t_lex2))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex2[0]))
            data["size"].append(len(t_lex2[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_lex2[0]))
            data["C"].append(C_tlex2_all)
            data["W"].append(W_tlex2_all)
            data["T"].append(T_tlex2_all)
            
            data["budget"].append(b) 
            data["theta_definition"].append("SVM")
            data["theta_operator"].append("SVM")
            data["time"].append(ti_lex_2)
            data["n_theta_min"].append(len(t_lex2))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex2[0]))
            data["size"].append(len(t_lex2[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_lex2[0]))
            data["C"].append(C_svm_tlex2)
            data["W"].append(W_svm_tlex2)
            data["T"].append(T_svm_tlex2)
            
            data["budget"].append(b) 
            data["theta_definition"].append("LPM")
            data["theta_operator"].append("LPM")
            data["time"].append(ti_lex_2)
            data["n_theta_min"].append(len(t_lex2))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex2[0]))
            data["size"].append(len(t_lex2[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_lex2[0]))
            data["C"].append(C_card_tlex2)
            data["W"].append(W_card_tlex2)
            data["T"].append(T_card_tlex2)
            
            ####LEX 3 
            data["budget"].append(b) 
            data["theta_definition"].append("LEX3")
            data["theta_operator"].append("UNION")
            data["time"].append(ti_lex_3)
            data["n_theta_min"].append(len(t_lex3))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex3_union))
            data["size"].append(len(t_lex3_union))
            data["sizes_sum"].append(sum(len(i) for i in t_lex3_union))
            data["C"].append(C_tlex3_union)
            data["W"].append(W_tlex3_union)
            data["T"].append(T_tlex3_union)
            
            data["budget"].append(b) 
            data["theta_definition"].append("LEX3")
            data["theta_operator"].append("RND")
            data["time"].append(ti_lex_3)
            data["n_theta_min"].append(len(t_lex3))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex3_rnd))
            data["size"].append(len(t_lex3_rnd))
            data["sizes_sum"].append(sum(len(i) for i in t_lex3_rnd))
            data["C"].append(C_tlex3_rnd)
            data["W"].append(W_tlex3_rnd)
            data["T"].append(T_tlex3_rnd)
            
            data["budget"].append(b) 
            data["theta_definition"].append("LEX3")
            data["theta_operator"].append("ALL")
            data["time"].append(ti_lex_3)
            data["n_theta_min"].append(len(t_lex3))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex3[0]))
            data["size"].append(len(t_lex3[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_lex3[0]))
            data["C"].append(C_tlex3_all)
            data["W"].append(W_tlex3_all)
            data["T"].append(T_tlex3_all)
            
            data["budget"].append(b) 
            data["theta_definition"].append("SVM")
            data["theta_operator"].append("SVM")
            data["time"].append(ti_lex_3)
            data["n_theta_min"].append(len(t_lex3))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex3[0]))
            data["size"].append(len(t_lex3[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_lex3[0]))
            data["C"].append(C_svm_tlex3)
            data["W"].append(W_svm_tlex3)
            data["T"].append(T_svm_tlex3)
            
            data["budget"].append(b) 
            data["theta_definition"].append("CARD")
            data["theta_operator"].append("CARD")
            data["time"].append(ti_lex_3)
            data["n_theta_min"].append(len(t_lex3))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_lex3[0]))
            data["size"].append(len(t_lex3[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_lex3[0]))
            data["C"].append(C_card_tlex3)
            data["W"].append(W_card_tlex3)
            data["T"].append(T_card_tlex3)
            
            
            ####VARIANCE  
            data["budget"].append(b) 
            data["theta_definition"].append("VAR")
            data["theta_operator"].append("UNION")
            data["time"].append(ti_var)
            data["n_theta_min"].append(len(t_var))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_var_union))
            data["size"].append(len(t_var_union))
            data["sizes_sum"].append(sum(len(i) for i in t_var_union))
            data["C"].append(C_var_union)
            data["W"].append(W_var_union)
            data["T"].append(T_var_union)
            
            data["budget"].append(b) 
            data["theta_definition"].append("VAR")
            data["theta_operator"].append("RND")
            data["time"].append(ti_var)
            data["n_theta_min"].append(len(t_var))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_var_rnd))
            data["size"].append(len(t_var_rnd))
            data["sizes_sum"].append(sum(len(i) for i in t_var_rnd))
            data["C"].append(C_var_rnd)
            data["W"].append(W_var_rnd)
            data["T"].append(T_var_rnd)
            
            data["budget"].append(b) 
            data["theta_definition"].append("VAR")
            data["theta_operator"].append("ALL")
            data["time"].append(ti_var)
            data["n_theta_min"].append(len(t_var))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_var[0]))
            data["size"].append(len(t_var[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_var[0]))
            data["C"].append(C_var_all)
            data["W"].append(W_var_all)
            data["T"].append(T_var_all)
            
            data["budget"].append(b) 
            data["theta_definition"].append("SVM")
            data["theta_operator"].append("SVM")
            data["time"].append(ti_var)
            data["n_theta_min"].append(len(t_var))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_var[0]))
            data["size"].append(len(t_var[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_var[0]))
            data["C"].append(C_svm_var)
            data["W"].append(W_svm_var)
            data["T"].append(T_svm_var)
            
            
            data["budget"].append(b) 
            data["theta_definition"].append("CARD")
            data["theta_operator"].append("CARD")
            data["time"].append(ti_var)
            data["n_theta_min"].append(len(t_var))
            data["n_preferences"].append(len(prf))
            data["additivity"].append(additivity(t_var[0]))
            data["size"].append(len(t_var[0]))
            data["sizes_sum"].append(sum(len(i) for i in t_var[0]))
            data["C"].append(C_card_var)
            data["W"].append(W_card_var)
            data["T"].append(T_card_var)
            
        
            
            df = pd.DataFrame(data)
            df.to_csv("theta_definitions_comparisons_with_cardinals_3.csv")
            #print(df)
# Out:
# solved connivent:  1  with [(0,)]
# solved connivent:  2  with [(0,), (2,), (1,), (4,)]
# solved connivent:  3  with [(0,), (2,), (1,), (4,), (3,)]
# Lex2 took 0.15
# Lex3 took 0.15
# Var took 0.12
# repetition = 0, b = 3, srep = 0, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 3, srep = 1, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 3, srep = 2, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 3, srep = 3, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 3, srep = 4, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 3, srep = 5, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 3, srep = 6, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 3, srep = 7, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 3, srep = 8, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 3, srep = 9, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(0,)]
# solved connivent:  2  with [(0,), (2,), (1,), (4,)]
# solved connivent:  3  with [(0,), (2,), (1,), (4,), (3,)]
# Lex2 took 0.15
# Lex3 took 0.15
# Var took 0.16
# repetition = 0, b = 4, srep = 0, npref = 9
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 4, srep = 1, npref = 9
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 4, srep = 2, npref = 9
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 4, srep = 3, npref = 9
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 4, srep = 4, npref = 9
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 4, srep = 5, npref = 9
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 4, srep = 6, npref = 9
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 4, srep = 7, npref = 9
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 4, srep = 8, npref = 9
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 4, srep = 9, npref = 9
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(1,), (0,)]
# solved connivent:  2  with [(1,), (0,), (3,)]
# solved connivent:  3  with [(1,), (0,), (3,), (2,), (4,)]
# Lex2 took 0.15
# Lex3 took 0.15
# Var took 0.18
# repetition = 0, b = 5, srep = 0, npref = 12
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 5, srep = 1, npref = 12
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 5, srep = 2, npref = 12
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 5, srep = 3, npref = 12
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 5, srep = 4, npref = 12
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 5, srep = 5, npref = 12
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 5, srep = 6, npref = 12
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 5, srep = 7, npref = 12
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 5, srep = 8, npref = 12
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 5, srep = 9, npref = 12
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(3,), (1,), (4,)]
# solved connivent:  2  with [(3,), (1,), (4,), (0,)]
# Lex2 took 0.15
# Lex3 took 0.15
# Var took 0.18
# repetition = 0, b = 6, srep = 0, npref = 17
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 6, srep = 1, npref = 17
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 6, srep = 2, npref = 17
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 6, srep = 3, npref = 17
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 6, srep = 4, npref = 17
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 6, srep = 5, npref = 17
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 6, srep = 6, npref = 17
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 6, srep = 7, npref = 17
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 6, srep = 8, npref = 17
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 6, srep = 9, npref = 17
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(4,)]
# solved connivent:  2  with [(4,), (0,), (3,)]
# solved connivent:  3  with [(4,), (0,), (3,), (1,)]
# solved connivent:  4  with [(4,), (0,), (3,), (1,), (2,)]
# Lex2 took 0.11
# Lex3 took 0.10
# Var took 0.13
# repetition = 0, b = 7, srep = 0, npref = 24
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 7, srep = 1, npref = 24
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 7, srep = 2, npref = 24
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 7, srep = 3, npref = 24
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 7, srep = 4, npref = 24
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 7, srep = 5, npref = 24
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 7, srep = 6, npref = 24
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 7, srep = 7, npref = 24
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 7, srep = 8, npref = 24
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 7, srep = 9, npref = 24
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(3,), (2,)]
# solved connivent:  2  with [(3,), (2,), (1,)]
# solved connivent:  3  with [(3,), (2,), (1,), (4,)]
# solved connivent:  4  with [(3,), (2,), (1,), (4,), (0,)]
# Lex2 took 0.11
# Lex3 took 0.12
# Var took 0.14
# repetition = 0, b = 8, srep = 0, npref = 31
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 8, srep = 1, npref = 31
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 8, srep = 2, npref = 31
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 8, srep = 3, npref = 31
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 8, srep = 4, npref = 31
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 8, srep = 5, npref = 31
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 8, srep = 6, npref = 31
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 8, srep = 7, npref = 31
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 8, srep = 8, npref = 31
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 8, srep = 9, npref = 31
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(1,)]
# solved connivent:  2  with [(1,), (2,), (3,)]
# solved connivent:  3  with [(1,), (2,), (3,), (0,)]
# solved connivent:  4  with [(1,), (2,), (3,), (0,), (4,)]
# Lex2 took 0.11
# Lex3 took 0.11
# Var took 0.13
# repetition = 0, b = 9, srep = 0, npref = 39
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 9, srep = 1, npref = 39
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 9, srep = 2, npref = 39
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 9, srep = 3, npref = 39
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 9, srep = 4, npref = 39
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 9, srep = 5, npref = 39
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 9, srep = 6, npref = 39
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 9, srep = 7, npref = 39
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 9, srep = 8, npref = 39
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 9, srep = 9, npref = 39
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(2,)]
# solved connivent:  2  with [(2,), (1,)]
# solved connivent:  3  with [(2,), (1,), (0,), (3,)]
# solved connivent:  4  with [(2,), (1,), (0,), (3,), (4,)]
# Lex2 took 0.11
# Lex3 took 0.11
# Var took 0.13
# repetition = 0, b = 10, srep = 0, npref = 47
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 10, srep = 1, npref = 47
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 10, srep = 2, npref = 47
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 10, srep = 3, npref = 47
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 10, srep = 4, npref = 47
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 10, srep = 5, npref = 47
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 10, srep = 6, npref = 47
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 10, srep = 7, npref = 47
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 10, srep = 8, npref = 47
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 10, srep = 9, npref = 47
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(2,)]
# solved connivent:  2  with [(2,), (3,), (0,)]
# solved connivent:  3  with [(2,), (3,), (0,), (1,)]
# solved connivent:  4  with [(2,), (3,), (0,), (1,), (4,)]
# Lex2 took 0.12
# Lex3 took 0.13
# Var took 0.14
# repetition = 0, b = 11, srep = 0, npref = 56
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 11, srep = 1, npref = 56
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 11, srep = 2, npref = 56
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 11, srep = 3, npref = 56
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 11, srep = 4, npref = 56
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 11, srep = 5, npref = 56
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 11, srep = 6, npref = 56
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 11, srep = 7, npref = 56
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 11, srep = 8, npref = 56
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 11, srep = 9, npref = 56
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(0,)]
# solved connivent:  2  with [(0,), (1,)]
# solved connivent:  3  with [(0,), (1,), (2,)]
# solved connivent:  4  with [(0,), (1,), (2,), (4,)]
# solved connivent:  5  with [(0,), (1,), (2,), (4,), (3,)]
# Lex2 took 0.12
# Lex3 took 0.13
# Var took 0.14
# repetition = 0, b = 12, srep = 0, npref = 65
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 12, srep = 1, npref = 65
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 12, srep = 2, npref = 65
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 12, srep = 3, npref = 65
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 12, srep = 4, npref = 65
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 12, srep = 5, npref = 65
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 12, srep = 6, npref = 65
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 12, srep = 7, npref = 65
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 12, srep = 8, npref = 65
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 12, srep = 9, npref = 65
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(0,)]
# solved connivent:  2  with [(0,), (3,), (2,)]
# solved connivent:  3  with [(0,), (3,), (2,), (1,)]
# solved connivent:  4  with [(0,), (3,), (2,), (1,), (4,)]
# Lex2 took 0.17
# Lex3 took 0.14
# Var took 0.17
# repetition = 0, b = 13, srep = 0, npref = 76
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 13, srep = 1, npref = 76
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 13, srep = 2, npref = 76
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 13, srep = 3, npref = 76
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 13, srep = 4, npref = 76
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 13, srep = 5, npref = 76
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 13, srep = 6, npref = 76
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 13, srep = 7, npref = 76
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 13, srep = 8, npref = 76
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 13, srep = 9, npref = 76
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(3,), (2,)]
# solved connivent:  2  with [(3,), (2,), (1,)]
# solved connivent:  3  with [(3,), (2,), (1,), (0,)]
# solved connivent:  4  with [(3,), (2,), (1,), (0,), (4,)]
# Lex2 took 0.13
# Lex3 took 0.12
# Var took 0.12
# repetition = 0, b = 14, srep = 0, npref = 87
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 14, srep = 1, npref = 87
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 14, srep = 2, npref = 87
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 14, srep = 3, npref = 87
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 14, srep = 4, npref = 87
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 14, srep = 5, npref = 87
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 14, srep = 6, npref = 87
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 14, srep = 7, npref = 87
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 14, srep = 8, npref = 87
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 14, srep = 9, npref = 87
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(3,), (2,)]
# solved connivent:  2  with [(3,), (2,), (1,)]
# solved connivent:  3  with [(3,), (2,), (1,), (0,)]
# solved connivent:  4  with [(3,), (2,), (1,), (0,), (4,)]
# Lex2 took 0.14
# Lex3 took 0.14
# Var took 0.11
# repetition = 0, b = 15, srep = 0, npref = 98
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 15, srep = 1, npref = 98
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 15, srep = 2, npref = 98
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 15, srep = 3, npref = 98
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 15, srep = 4, npref = 98
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 15, srep = 5, npref = 98
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 15, srep = 6, npref = 98
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 15, srep = 7, npref = 98
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 15, srep = 8, npref = 98
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 15, srep = 9, npref = 98
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(3,), (0,)]
# solved connivent:  2  with [(3,), (0,), (1,)]
# solved connivent:  3  with [(3,), (0,), (1,), (2,)]
# solved connivent:  4  with [(3,), (0,), (1,), (2,), (4,)]
# solved connivent:  5  with [(3,), (0,), (1,), (2,), (4,), (0, 1), (0, 3), (1, 2), (2, 3)]
# Lex2 took 3.57
# Lex3 took 0.59
# Var took 0.35
# repetition = 0, b = 16, srep = 0, npref = 110
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 16, srep = 1, npref = 110
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 16, srep = 2, npref = 110
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 16, srep = 3, npref = 110
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 16, srep = 4, npref = 110
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 16, srep = 5, npref = 110
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 16, srep = 6, npref = 110
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 16, srep = 7, npref = 110
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 16, srep = 8, npref = 110
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 16, srep = 9, npref = 110
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# solved connivent:  1  with [(2,)]
# solved connivent:  2  with [(2,), (0,)]
# solved connivent:  3  with [(2,), (0,), (1,)]
# solved connivent:  4  with [(2,), (0,), (1,), (4,)]
# solved connivent:  5  with [(2,), (0,), (1,), (4,), (3,)]
# solved connivent:  6  with [(2,), (0,), (1,), (4,), (3,), (0, 1), (1, 4), (0, 4), (0, 3), (3, 4), (1, 2), (2, 3), (2, 4), (0, 2)]
# Lex2 took 3.56
# Lex3 took 0.62
# Var took 0.39
# repetition = 0, b = 17, srep = 0, npref = 122
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 17, srep = 1, npref = 122
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 17, srep = 2, npref = 122
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 17, srep = 3, npref = 122
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 17, srep = 4, npref = 122
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 17, srep = 5, npref = 122
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 17, srep = 6, npref = 122
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 17, srep = 7, npref = 122
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 17, srep = 8, npref = 122
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# repetition = 0, b = 17, srep = 9, npref = 122
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_1_2..
# ...
# Lex2 took 2.38
# Lex3 took 1.61
# Var took 0.55
# repetition = 3, b = 22, srep = 0, npref = 199
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 22, srep = 1, npref = 199
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 22, srep = 2, npref = 199
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 22, srep = 3, npref = 199
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 22, srep = 4, npref = 199
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 22, srep = 5, npref = 199
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 22, srep = 6, npref = 199
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 22, srep = 7, npref = 199
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 22, srep = 8, npref = 199
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 22, srep = 9, npref = 199
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# solved connivent:  1  with [(3,), (4,)]
# solved connivent:  2  with [(3,), (4,), (2,), (1,)]
# solved connivent:  3  with [(3,), (4,), (2,), (1,), (2, 4), (3, 4), (1, 4)]
# solved connivent:  4  with [(3,), (4,), (2,), (1,), (2, 4), (3, 4), (1, 4), (0,)]
# solved connivent:  5  with [(3,), (4,), (2,), (1,), (2, 4), (3, 4), (1, 4), (0,), (0, 1), (0, 3)]
# solved connivent:  6  with [(3,), (4,), (2,), (1,), (2, 4), (3, 4), (1, 4), (0,), (0, 1), (0, 3), (0, 2), (1, 3), (0, 4)]
# solved connivent:  7  with [(3,), (4,), (2,), (1,), (2, 4), (3, 4), (1, 4), (0,), (0, 1), (0, 3), (0, 2), (1, 3), (0, 4), (2, 3)]
# solved connivent:  8  with [(3,), (4,), (2,), (1,), (2, 4), (3, 4), (1, 4), (0,), (0, 1), (0, 3), (0, 2), (1, 3), (0, 4), (2, 3), (2, 3, 4), (1, 3, 4), (0, 3, 4), (0, 1, 3)]
# solved connivent:  9  with [(3,), (4,), (2,), (1,), (2, 4), (3, 4), (1, 4), (0,), (0, 1), (0, 3), (0, 2), (1, 3), (0, 4), (2, 3), (2, 3, 4), (1, 3, 4), (0, 3, 4), (0, 1, 3), (1, 2)]
# Lex2 took 2.44
# Lex3 took 0.79
# Var took 0.50
# repetition = 3, b = 23, srep = 0, npref = 218
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 23, srep = 1, npref = 218
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 23, srep = 2, npref = 218
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 23, srep = 3, npref = 218
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 23, srep = 4, npref = 218
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 23, srep = 5, npref = 218
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 23, srep = 6, npref = 218
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 23, srep = 7, npref = 218
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 23, srep = 8, npref = 218
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 23, srep = 9, npref = 218
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# solved connivent:  1  with [(3,)]
# solved connivent:  2  with [(3,), (2,), (4,)]
# solved connivent:  3  with [(3,), (2,), (4,), (1,)]
# solved connivent:  4  with [(3,), (2,), (4,), (1,), (3, 4), (2, 4)]
# solved connivent:  5  with [(3,), (2,), (4,), (1,), (3, 4), (2, 4), (1, 4)]
# solved connivent:  6  with [(3,), (2,), (4,), (1,), (3, 4), (2, 4), (1, 4), (0, 2), (0, 4)]
# solved connivent:  7  with [(3,), (2,), (4,), (1,), (3, 4), (2, 4), (1, 4), (0, 2), (0, 4), (0,)]
# solved connivent:  8  with [(3,), (2,), (4,), (1,), (3, 4), (2, 4), (1, 4), (0, 2), (0, 4), (0,), (0, 1), (0, 3)]
# solved connivent:  9  with [(3,), (2,), (4,), (1,), (3, 4), (2, 4), (1, 4), (0, 2), (0, 4), (0,), (0, 1), (0, 3), (2, 3, 4), (0, 2, 3), (0, 2, 4), (0, 1, 4)]
# Lex2 took 1.79
# Lex3 took 0.57
# Var took 0.33
# repetition = 3, b = 24, srep = 0, npref = 241
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 24, srep = 1, npref = 241
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 24, srep = 2, npref = 241
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 24, srep = 3, npref = 241
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 24, srep = 4, npref = 241
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 24, srep = 5, npref = 241
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 24, srep = 6, npref = 241
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 24, srep = 7, npref = 241
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 24, srep = 8, npref = 241
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# repetition = 3, b = 24, srep = 9, npref = 241
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# Warning: Multi-objective has been converted to single objective: -l#0_1_2_3#0_3_4..
# solved connivent:  1  with [(3,), (1,)]
# solved connivent:  2  with [(3,), (1,), (2,)]
# Lex2 took 0.09
# Lex3 took 0.10
# Var took 0.08
# repetition = 4, b = 3, srep = 0, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# repetition = 4, b = 3, srep = 1, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# repetition = 4, b = 3, srep = 2, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# repetition = 4, b = 3, srep = 3, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# repetition = 4, b = 3, srep = 4, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# repetition = 4, b = 3, srep = 5, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# repetition = 4, b = 3, srep = 6, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# repetition = 4, b = 3, srep = 7, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# repetition = 4, b = 3, srep = 8, npref = 5
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# Warning: Multi-objective has been converted to single objective: -l#0#0_1_3-l#0#0..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_143/171383350.py in <module>
#     105
#     106
# --> 107             prf_var_union = predict_from_theta(t_var_union, prf, test_subsets)
#     108             prf_var_rnd = predict_from_theta(t_var_rnd, prf, test_subsets)
#     109             prf_var_all = predict_from_mult_thetas(t_var[:10], prf, test_subsets)
#
# /tmp/ipykernel_143/56132996.py in predict_from_theta(theta, p, subsets)
#      56 def predict_from_theta(theta, p, subsets):
#      57     mdl = utility_polyhedron(p.items, theta, p)
# ---> 58     prf = ordinal_peferences(p.items, subsets, mdl)
#      59     return prf
#      60
#
# ~/Projects/PMTK-CPLEX/PMTK/utility/utility_solver.py in ordinal_peferences(items, subsets, mdl)
#      39         for i_2 in range(i_1 + 1, len(subsets)):
#      40             s_2 = subsets[i_2]
# ---> 41             r = ordinal_dominance(s_1, s_2, mdl)
#      42             if r == "SUP":
#      43                 prf.add_preference(s_1, s_2)
#
# ~/Projects/PMTK-CPLEX/PMTK/utility/utility_solver.py in ordinal_dominance(s_1, s_2, mdl)
#      18
#      19 def ordinal_dominance(s_1, s_2, mdl):
# ---> 20     e = get_MPR(s_1,s_2,mdl)
#      21     e2 = get_MPR(s_2, s_1, mdl)
#      22     #print(f"x={s_1}, y = {s_2}, e1 = {e}, e2 = {e2}")
#
# ~/Projects/PMTK-CPLEX/PMTK/utility/utility_solver.py in get_MPR(s_1, s_2, mdl)
#      13     mdl.maximize_static_lex([-mdl.slack_sum, e])
#      14     mdl.solve()
# ---> 15     v = e.solution_value
#      16     mdl.remove_constraint(c)
#      17     return v
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/docplex/mp/linear.py in solution_value(self)
#    1093                 if the model has not been solved.
#    1094         """
# -> 1095         return super().solution_value
#    1096
#    1097     def _raw_solution_value(self, s=None):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/docplex/mp/basic.py in solution_value(self)
#      74     def solution_value(self):
#      75         self.model._check_has_solution()
# ---> 76         raw = self._raw_solution_value()
#      77         return self._round_if_discrete(raw)
#      78
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/docplex/mp/linear.py in _raw_solution_value(self, s)
#    1100         sol = s or self._model.solution
#    1101         for var, koef in self.iter_terms():
# -> 1102             val += koef * sol._get_var_value(var)
#    1103         return val
#    1104
#
# KeyboardInterrupt:
